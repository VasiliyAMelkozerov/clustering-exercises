# %%
import pandas as pd
import seaborn as sns
import acquire
import matplotlib as plt

# %% [markdown]
# ## Acquire/Preparing (Wrangling)

# %%
#what does the data look like
df = acquire.zillow_data()
df
# Out:
#        parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 0      17173851                     NaN          NaN                  261.0
# 1      10821119                     NaN          NaN                  261.0
# 2      11007640                     NaN          NaN                  261.0
# 3      11457850                     NaN          NaN                  261.0
# 4      12591550                     NaN          NaN                  261.0
# ...         ...                     ...          ...                    ...
# 52437  12885754                     NaN          NaN                  261.0
# 52438  13869000                     NaN          NaN                  261.0
# 52439  13890509                     NaN          NaN                  261.0
# 52440  17246810                     NaN          NaN                  261.0
# 52441  14360869                     NaN          NaN                  261.0
#
#        heatingorsystemtypeid buildingclasstypeid  architecturalstyletypeid  \
# 0                        NaN                None                       NaN
# 1                        2.0                None                       NaN
# 2                        2.0                None                       NaN
# 3                        7.0                None                       NaN
# 4                        2.0                None                       NaN
# ...                      ...                 ...                       ...
# 52437                    7.0                None                       NaN
# 52438                    NaN                None                       NaN
# 52439                    NaN                None                       NaN
# 52440                    NaN                None                       NaN
# 52441                    NaN                None                       NaN
#
#        airconditioningtypeid       id  basementsqft  ...       id  logerror  \
# 0                        NaN      787           NaN  ...    389.0  0.088469
# 1                        NaN     1702           NaN  ...    402.0  0.025629
# 2                        1.0     2412           NaN  ...   2699.0  0.020360
# 3                        NaN     3770           NaN  ...   2229.0  0.054233
# 4                        NaN     8197           NaN  ...   3038.0 -0.016170
# ...                      ...      ...           ...  ...      ...       ...
# 52437                    NaN  2976765           NaN  ...  42657.0  0.515289
# 52438                    NaN  2977815           NaN  ...  32297.0  0.009512
# 52439                    NaN  2977914           NaN  ...  28537.0 -0.031048
# 52440                    NaN  2980979           NaN  ...   8396.0 -0.031665
# 52441                    NaN  2982193           NaN  ...  71174.0  0.086432
#
#        transactiondate  airconditioningdesc  architecturalstyledesc  \
# 0           2017-01-03                 None                    None
# 1           2017-01-03                 None                    None
# 2           2017-01-12              Central                    None
# 3           2017-01-11                 None                    None
# 4           2017-01-13                 None                    None
# ...                ...                  ...                     ...
# 52437       2017-06-01                 None                    None
# 52438       2017-05-02                 None                    None
# 52439       2017-04-21                 None                    None
# 52440       2017-02-07                 None                    None
# 52441       2017-08-29                 None                    None
#
#        buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
# 0                   None                 None  Single Family Residential
# 1                   None              Central  Single Family Residential
# 2                   None              Central  Single Family Residential
# 3                   None           Floor/Wall  Single Family Residential
# 4                   None              Central  Single Family Residential
# ...                  ...                  ...                        ...
# 52437               None           Floor/Wall  Single Family Residential
# 52438               None                 None  Single Family Residential
# 52439               None                 None  Single Family Residential
# 52440               None                 None  Single Family Residential
# 52441               None                 None  Single Family Residential
#
#       storydesc typeconstructiondesc
# 0          None                 None
# 1          None                 None
# 2          None                 None
# 3          None                 None
# 4          None                 None
# ...         ...                  ...
# 52437      None                 None
# 52438      None                 None
# 52439      None                 None
# 52440      None                 None
# 52441      None                 None
#
# [52442 rows x 69 columns]

# %%
#let's get an idea of what the logerror is and looks like
df.logerror.describe()
#the max and min are pretty close apart 
#i want just the outliers
#i do not know what the negative or positive logerror mean wether they over or underestimated the price
#better here to over estimate then underestimate
#|| absolute value
# Out:
# count    52441.000000
# mean         0.018298
# std          0.177501
# min         -4.655420
# 25%         -0.024639
# 50%          0.007011
# 75%          0.040692
# max          5.262999
# Name: logerror, dtype: float64

# %% [markdown]
# Ask at least 5 questions about the data, keeping in mind that your target variable is logerror. e.g. Is logerror significantly different for properties in LA County vs Orange County vs Ventura County?

# %% [markdown]
# <b>Where are the upper outliers</b>

# %%
#this closes us in on the problem we are looking at
upper_error = df[df.logerror >= .1]
upper_error
# Out:
#        parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 5      12755884                     NaN          NaN                  261.0
# 12     10736968                     NaN          NaN                  261.0
# 20     12588379                     NaN          NaN                  261.0
# 28     11920295                     NaN          NaN                  261.0
# 34     11010220                     NaN          NaN                  261.0
# ...         ...                     ...          ...                    ...
# 52411  12469375                     NaN          NaN                  261.0
# 52421  11970685                     NaN          NaN                  261.0
# 52432  14445371                     NaN          NaN                  261.0
# 52436  12087743                     NaN          NaN                  261.0
# 52437  12885754                     NaN          NaN                  261.0
#
#        heatingorsystemtypeid buildingclasstypeid  architecturalstyletypeid  \
# 5                        2.0                None                       NaN
# 12                       2.0                None                       NaN
# 20                      20.0                None                       NaN
# 28                       2.0                None                       NaN
# 34                       2.0                None                       NaN
# ...                      ...                 ...                       ...
# 52411                    7.0                None                       NaN
# 52421                    2.0                None                       NaN
# 52432                    NaN                None                       NaN
# 52436                    7.0                None                       NaN
# 52437                    7.0                None                       NaN
#
#        airconditioningtypeid       id  basementsqft  ...       id  logerror  \
# 5                        1.0     8864           NaN  ...   1192.0  0.442837
# 12                       1.0    16242           NaN  ...     81.0  0.116061
# 20                       NaN    23020           NaN  ...   3420.0  0.106150
# 28                       1.0    28801           NaN  ...   1857.0  0.233307
# 34                       1.0    32246           NaN  ...   3691.0  0.180782
# ...                      ...      ...           ...  ...      ...       ...
# 52411                    NaN  2915236           NaN  ...  11875.0  0.137449
# 52421                    NaN  2928233           NaN  ...  45724.0  0.221642
# 52432                    NaN  2965254           NaN  ...  63175.0  0.594828
# 52436                    NaN  2973484           NaN  ...  31255.0  0.175492
# 52437                    NaN  2976765           NaN  ...  42657.0  0.515289
#
#        transactiondate  airconditioningdesc  architecturalstyledesc  \
# 5           2017-01-06              Central                    None
# 12          2017-01-02              Central                    None
# 20          2017-01-17                 None                    None
# 28          2017-01-10              Central                    None
# 34          2017-01-18              Central                    None
# ...                ...                  ...                     ...
# 52411       2017-02-23                 None                    None
# 52421       2017-06-13                 None                    None
# 52432       2017-08-01                 None                    None
# 52436       2017-04-28                 None                    None
# 52437       2017-06-01                 None                    None
#
#        buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
# 5                   None              Central  Single Family Residential
# 12                  None              Central  Single Family Residential
# 20                  None                Solar  Single Family Residential
# 28                  None              Central  Single Family Residential
# 34                  None              Central  Single Family Residential
# ...                  ...                  ...                        ...
# 52411               None           Floor/Wall  Single Family Residential
# 52421               None              Central  Single Family Residential
# 52432               None                 None  Single Family Residential
# 52436               None           Floor/Wall  Single Family Residential
# 52437               None           Floor/Wall  Single Family Residential
#
#       storydesc typeconstructiondesc
# 5          None                 None
# 12         None                 None
# 20         None                 None
# 28         None                 None
# 34         None                 None
# ...         ...                  ...
# 52411      None                 None
# 52421      None                 None
# 52432      None                 None
# 52436      None                 None
# 52437      None                 None
#
# [5502 rows x 69 columns]

# %%
#getting a sense of all of the columns imported
df.columns
# Out:
# Index(['parcelid', 'typeconstructiontypeid', 'storytypeid',
#        'propertylandusetypeid', 'heatingorsystemtypeid', 'buildingclasstypeid',
#        'architecturalstyletypeid', 'airconditioningtypeid', 'id',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid',
#        'calculatedbathnbr', 'decktypeid', 'finishedfloor1squarefeet',
#        'calculatedfinishedsquarefeet', 'finishedsquarefeet12',
#        'finishedsquarefeet13', 'finishedsquarefeet15', 'finishedsquarefeet50',
#        'finishedsquarefeet6', 'fips', 'fireplacecnt', 'fullbathcnt',
#        'garagecarcnt', 'garagetotalsqft', 'hashottuborspa', 'latitude',
#        'longitude', 'lotsizesquarefeet', 'poolcnt', 'poolsizesum',
#        'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertycountylandusecode', 'propertyzoningdesc',
#        'rawcensustractandblock', 'regionidcity', 'regionidcounty',
#        'regionidneighborhood', 'regionidzip', 'roomcnt', 'threequarterbathnbr',
#        'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
#        'numberofstories', 'fireplaceflag', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
#        'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear',
#        'censustractandblock', 'id', 'logerror', 'transactiondate',
#        'airconditioningdesc', 'architecturalstyledesc', 'buildingclassdesc',
#        'heatingorsystemdesc', 'propertylandusedesc', 'storydesc',
#        'typeconstructiondesc'],
#       dtype='object')

# %%
#let's plot out what the logerror lands around price
sns.relplot(x=df.taxvaluedollarcnt ,y=df.logerror, data=df)

# %%
#what does the logerror look like on a grand scale
df.logerror.hist()
# Out:
# <AxesSubplot:>

# %%
#can i make a relplot that shoes me where this distribution is
df.isnull().sum()
# Out:
# parcelid                      0
# typeconstructiontypeid    52366
# storytypeid               52395
# propertylandusetypeid         0
# heatingorsystemtypeid     18507
#                           ...
# buildingclassdesc         52442
# heatingorsystemdesc       18507
# propertylandusedesc           0
# storydesc                 52395
# typeconstructiondesc      52366
# Length: 69, dtype: int64

# %% [markdown]
# <b>About 10% of the data has upper outliers</b>

# %%
#checking how many values use propertylandusetypeid
df.propertylandusetypeid.value_counts()
# Out:
# 261.0    52441
# 279.0        1
# Name: propertylandusetypeid, dtype: int64

# %%
#looking for what story type even is
df.storytypeid
#in hind sight i think it means the amount of floors
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 52437   NaN
# 52438   NaN
# 52439   NaN
# 52440   NaN
# 52441   NaN
# Name: storytypeid, Length: 52442, dtype: float64

# %%
#what i can also do with the data is 
#what does logerror really represent?
# i now have the information

# %% [markdown]
# > Your audience for this project is a data science team. The presentation will consist of a notebook demo of the discoveries you made and work you have done related to uncovering what the drivers of the error in the zestimate is.
# <br>
# <a href="https://ds.codeup.com/clustering/project/">Project Source</a>

# %% [markdown]
# ><i>𝑙𝑜𝑔𝑒𝑟𝑟𝑜𝑟=𝑙𝑜𝑔(𝑍𝑒𝑠𝑡𝑖𝑚𝑎𝑡𝑒)−𝑙𝑜𝑔(𝑆𝑎𝑙𝑒𝑃𝑟𝑖𝑐𝑒)</i>
# <br>
# <a href="https://www.kaggle.com/competitions/zillow-prize-1/data">from zillow website</a>

# %% [markdown]
# <div>This series of observations on trying to understand logerror has led me back to the acquireing stage to narrow in what I am looking for. From here in order to head towards my MVP model I shall no longer mess with the data coming in. Rather here in I will explore and find what I will. Exploration can take a while so it is best I set up goals.</div>
# > positive log error means that the price was overestimated
# > negative log error means that the price was underestimated

# %% [markdown]
# <div>Since I am going to re-acquire my data I can now plan out where and how I am going to handle the outliers, we handle outliers because it messes with our machine learnign accuracy in a negative way.</div>

# %% [markdown]
# <div>So this then begs the question what is a threshold I can set to where we need to start worrying about. It would take a good bit of time to have a great reason mathematically. For now maybe I can look at where the error lies in terms of the described info of logerror. Just pick a number (|.03|), fine I will change it. I just realised that I will need both a lower and upper bound limits to control the amount of data coming through. In normal speak that is, handle outliers. The upper bound threshold will be 3 while the lower bound threshold is .03 </div>

# %% [markdown]
# Currently the SQL server is on the fritz so I am going to have to move on as if I have all of the data with me

# %%
#what columns can I drop that don't yeild much information?
#I do not have any leads just yet
df.head(3)
# Out:
#    parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 0  17173851                     NaN          NaN                  261.0
# 1  10821119                     NaN          NaN                  261.0
# 2  11007640                     NaN          NaN                  261.0
#
#    heatingorsystemtypeid buildingclasstypeid  architecturalstyletypeid  \
# 0                    NaN                None                       NaN
# 1                    2.0                None                       NaN
# 2                    2.0                None                       NaN
#
#    airconditioningtypeid    id  basementsqft  ...      id  logerror  \
# 0                    NaN   787           NaN  ...   389.0  0.088469
# 1                    NaN  1702           NaN  ...   402.0  0.025629
# 2                    1.0  2412           NaN  ...  2699.0  0.020360
#
#    transactiondate  airconditioningdesc  architecturalstyledesc  \
# 0       2017-01-03                 None                    None
# 1       2017-01-03                 None                    None
# 2       2017-01-12              Central                    None
#
#    buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
# 0               None                 None  Single Family Residential
# 1               None              Central  Single Family Residential
# 2               None              Central  Single Family Residential
#
#   storydesc typeconstructiondesc
# 0      None                 None
# 1      None                 None
# 2      None                 None
#
# [3 rows x 69 columns]

# %%
#wait why am i dropping my columns
# df.isna().value_counts()

# %%
#this lovely bit of code was handed to me by Ryan Orsinger
outlies = df[(df.logerror >= 0.03) | (df.logerror <= -0.03)]
#i am calling it outlies because i want to save the word outliers
outlies
# Out:
#        parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 0      17173851                     NaN          NaN                  261.0
# 3      11457850                     NaN          NaN                  261.0
# 5      12755884                     NaN          NaN                  261.0
# 6      13983750                     NaN          NaN                  261.0
# 8      14399561                     NaN          NaN                  261.0
# ...         ...                     ...          ...                    ...
# 52436  12087743                     NaN          NaN                  261.0
# 52437  12885754                     NaN          NaN                  261.0
# 52439  13890509                     NaN          NaN                  261.0
# 52440  17246810                     NaN          NaN                  261.0
# 52441  14360869                     NaN          NaN                  261.0
#
#        heatingorsystemtypeid buildingclasstypeid  architecturalstyletypeid  \
# 0                        NaN                None                       NaN
# 3                        7.0                None                       NaN
# 5                        2.0                None                       NaN
# 6                        NaN                None                       NaN
# 8                        NaN                None                       NaN
# ...                      ...                 ...                       ...
# 52436                    7.0                None                       NaN
# 52437                    7.0                None                       NaN
# 52439                    NaN                None                       NaN
# 52440                    NaN                None                       NaN
# 52441                    NaN                None                       NaN
#
#        airconditioningtypeid       id  basementsqft  ...       id  logerror  \
# 0                        NaN      787           NaN  ...    389.0  0.088469
# 3                        NaN     3770           NaN  ...   2229.0  0.054233
# 5                        1.0     8864           NaN  ...   1192.0  0.442837
# 6                        NaN    10930           NaN  ...   3247.0  0.087099
# 8                        NaN    12462           NaN  ...   2883.0  0.032578
# ...                      ...      ...           ...  ...      ...       ...
# 52436                    NaN  2973484           NaN  ...  31255.0  0.175492
# 52437                    NaN  2976765           NaN  ...  42657.0  0.515289
# 52439                    NaN  2977914           NaN  ...  28537.0 -0.031048
# 52440                    NaN  2980979           NaN  ...   8396.0 -0.031665
# 52441                    NaN  2982193           NaN  ...  71174.0  0.086432
#
#        transactiondate  airconditioningdesc  architecturalstyledesc  \
# 0           2017-01-03                 None                    None
# 3           2017-01-11                 None                    None
# 5           2017-01-06              Central                    None
# 6           2017-01-17                 None                    None
# 8           2017-01-13                 None                    None
# ...                ...                  ...                     ...
# 52436       2017-04-28                 None                    None
# 52437       2017-06-01                 None                    None
# 52439       2017-04-21                 None                    None
# 52440       2017-02-07                 None                    None
# 52441       2017-08-29                 None                    None
#
#        buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
# 0                   None                 None  Single Family Residential
# 3                   None           Floor/Wall  Single Family Residential
# 5                   None              Central  Single Family Residential
# 6                   None                 None  Single Family Residential
# 8                   None                 None  Single Family Residential
# ...                  ...                  ...                        ...
# 52436               None           Floor/Wall  Single Family Residential
# 52437               None           Floor/Wall  Single Family Residential
# 52439               None                 None  Single Family Residential
# 52440               None                 None  Single Family Residential
# 52441               None                 None  Single Family Residential
#
#       storydesc typeconstructiondesc
# 0          None                 None
# 3          None                 None
# 5          None                 None
# 6          None                 None
# 8          None                 None
# ...         ...                  ...
# 52436      None                 None
# 52437      None                 None
# 52439      None                 None
# 52440      None                 None
# 52441      None                 None
#
# [27872 rows x 69 columns]

# %% [markdown]
# Sweet! even though I have cut my original data set in half I should be able  to have enough to workthrough. From here in I can split the data before further investigating

# %%
train, validate, test = acquire.traintestsplit(outlies)
train, validate, test
# Out:
# (       parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
#  12665  11034859                     NaN          NaN                  261.0
#  21882  12414696                     NaN          NaN                  261.0
#  26080  11922321                     NaN          NaN                  261.0
#  5143   12833180                     NaN          NaN                  261.0
#  23225  12027183                     NaN          NaN                  261.0
#  ...         ...                     ...          ...                    ...
#  31979  13009641                     NaN          NaN                  261.0
#  29061  13860688                     NaN          NaN                  261.0
#  26733  11795660                     NaN          NaN                  261.0
#  37761  11450752                     NaN          NaN                  261.0
#  10815  14025543                     NaN          NaN                  261.0
#
#         heatingorsystemtypeid buildingclasstypeid  architecturalstyletypeid  \
#  12665                    7.0                None                       NaN
#  21882                    2.0                None                       NaN
#  26080                    7.0                None                       NaN
#  5143                     7.0                None                       NaN
#  23225                    7.0                None                       NaN
#  ...                      ...                 ...                       ...
#  31979                    2.0                None                       NaN
#  29061                    NaN                None                       NaN
#  26733                    2.0                None                       NaN
#  37761                    2.0                None                       NaN
#  10815                    NaN                None                       NaN
#
#         airconditioningtypeid       id  basementsqft  ...       id  logerror  \
#  12665                    NaN  1240408           NaN  ...  37656.0  0.312669
#  21882                    NaN   812926           NaN  ...  75915.0  0.191992
#  26080                    NaN    94865           NaN  ...  49392.0  0.073156
#  5143                     NaN  1694732           NaN  ...  51545.0 -0.044806
#  23225                    NaN   497992           NaN  ...   6839.0  0.743104
#  ...                      ...      ...           ...  ...      ...       ...
#  31979                    1.0  2336139           NaN  ...  39387.0 -0.100315
#  29061                    NaN  2873219           NaN  ...  10945.0 -0.046294
#  26733                    1.0  1386532           NaN  ...  21597.0 -0.761094
#  37761                    NaN  1435491           NaN  ...  20734.0  0.149855
#  10815                    NaN   697199           NaN  ...  41779.0  0.437876
#
#         transactiondate  airconditioningdesc  architecturalstyledesc  \
#  12665       2017-05-18                 None                    None
#  21882       2017-09-12                 None                    None
#  26080       2017-06-22                 None                    None
#  5143        2017-06-28                 None                    None
#  23225       2017-01-31                 None                    None
#  ...                ...                  ...                     ...
#  31979       2017-05-24              Central                    None
#  29061       2017-02-20                 None                    None
#  26733       2017-03-30              Central                    None
#  37761       2017-03-28                 None                    None
#  10815       2017-05-31                 None                    None
#
#         buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
#  12665               None           Floor/Wall  Single Family Residential
#  21882               None              Central  Single Family Residential
#  26080               None           Floor/Wall  Single Family Residential
#  5143                None           Floor/Wall  Single Family Residential
#  23225               None           Floor/Wall  Single Family Residential
#  ...                  ...                  ...                        ...
#  31979               None              Central  Single Family Residential
#  29061               None                 None  Single Family Residential
#  26733               None              Central  Single Family Residential
#  37761               None              Central  Single Family Residential
#  10815               None                 None  Single Family Residential
#
#        storydesc typeconstructiondesc
#  12665      None                 None
#  21882      None                 None
#  26080      None                 None
#  5143       None                 None
#  23225      None                 None
#  ...         ...                  ...
#  31979      None                 None
#  29061      None                 None
#  26733      None                 None
#  37761      None                 None
#  10815      None                 None
#
#  [15607 rows x 69 columns],
#         parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
#  27895  11148765                     NaN          NaN                  261.0
#  3641   13899563                     NaN          NaN                  261.0
#  32809  11216150                     NaN          NaN                  261.0
#  10998  12824675                     NaN          NaN                  261.0
#  44350  11299151                     NaN          NaN                  261.0
#  ...         ...                     ...          ...                    ...
#  8789   11103916                     NaN          NaN                  261.0
#  39851  12854971                     NaN          NaN                  261.0
#  36922  12288127                     NaN          NaN                  261.0
#  26887  14103815                     NaN          NaN                  261.0
#  25264  14332773                     NaN          NaN                  261.0
#
#         heatingorsystemtypeid buildingclasstypeid  architecturalstyletypeid  \
#  27895                    2.0                None                       NaN
#  3641                     NaN                None                       NaN
#  32809                    2.0                None                       NaN
#  10998                    7.0                None                       NaN
#  44350                    2.0                None                       NaN
#  ...                      ...                 ...                       ...
#  8789                     2.0                None                       NaN
#  39851                    2.0                None                       NaN
#  36922                    7.0                None                       NaN
#  26887                    NaN                None                       NaN
#  25264                    NaN                None                       NaN
#
#         airconditioningtypeid       id  basementsqft  ...       id  logerror  \
#  27895                    1.0   599603           NaN  ...  50960.0 -0.037155
#  3641                     NaN  1800720           NaN  ...  40404.0  0.327529
#  32809                    1.0   968892           NaN  ...  43187.0 -0.084791
#  10998                    NaN  1067838           NaN  ...  21168.0 -0.030826
#  44350                    1.0  2091357           NaN  ...  68651.0  0.136300
#  ...                      ...      ...           ...  ...      ...       ...
#  8789                     NaN  2865751           NaN  ...  36266.0  0.052813
#  39851                    NaN  2439961           NaN  ...  64424.0  0.091437
#  36922                    NaN  2899571           NaN  ...  35418.0  0.242231
#  26887                    NaN  1682125           NaN  ...  16232.0  0.068462
#  25264                    NaN  1503721           NaN  ...  16902.0  0.033577
#
#         transactiondate  airconditioningdesc  architecturalstyledesc  \
#  27895       2017-06-27              Central                    None
#  3641        2017-05-26                 None                    None
#  32809       2017-06-02              Central                    None
#  10998       2017-03-29                 None                    None
#  44350       2017-08-21              Central                    None
#  ...                ...                  ...                     ...
#  8789        2017-05-15                 None                    None
#  39851       2017-08-08                 None                    None
#  36922       2017-05-11                 None                    None
#  26887       2017-03-10                 None                    None
#  25264       2017-03-14                 None                    None
#
#         buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
#  27895               None              Central  Single Family Residential
#  3641                None                 None  Single Family Residential
#  32809               None              Central  Single Family Residential
#  10998               None           Floor/Wall  Single Family Residential
#  44350               None              Central  Single Family Residential
#  ...                  ...                  ...                        ...
#  8789                None              Central  Single Family Residential
#  39851               None              Central  Single Family Residential
#  36922               None           Floor/Wall  Single Family Residential
#  26887               None                 None  Single Family Residential
#  25264               None                 None  Single Family Residential
#
#        storydesc typeconstructiondesc
#  27895      None                 None
#  3641       None                 None
#  32809      None                 None
#  10998      None                 None
#  44350      None                 None
#  ...         ...                  ...
#  8789       None                 None
#  39851      None                 None
#  36922      None                 None
#  26887      None                 None
#  25264      None                 None
#
#  [6690 rows x 69 columns],
#         parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
#  7727   14435719                     NaN          NaN                  261.0
#  44139  10796102                     NaN          NaN                  261.0
#  247    11272513                     NaN          NaN                  261.0
#  42603  11284938                     NaN          NaN                  261.0
#  46973  10901026                     NaN          NaN                  261.0
#  ...         ...                     ...          ...                    ...
#  44472  14246881                     NaN          NaN                  261.0
#  30902  14421383                     NaN          NaN                  261.0
#  26124  17261860                     NaN          NaN                  261.0
#  50218  14418490                     NaN          NaN                  261.0
#  13140  17169459                     NaN          NaN                  261.0
#
#         heatingorsystemtypeid buildingclasstypeid  architecturalstyletypeid  \
#  7727                     6.0                None                       NaN
#  44139                    2.0                None                       NaN
#  247                      2.0                None                       NaN
#  42603                    2.0                None                       NaN
#  46973                    7.0                None                       NaN
#  ...                      ...                 ...                       ...
#  44472                    NaN                None                       NaN
#  30902                    NaN                None                       NaN
#  26124                    NaN                None                       NaN
#  50218                    NaN                None                       NaN
#  13140                    NaN                None                       NaN
#
#         airconditioningtypeid       id  basementsqft  ...       id  logerror  \
#  7727                     1.0   728590           NaN  ...  68613.0 -0.104635
#  44139                    NaN  1702072           NaN  ...  56918.0  0.039962
#  247                      1.0   282509           NaN  ...   1360.0  0.098017
#  42603                    1.0  1733607           NaN  ...  70368.0  0.037205
#  46973                    NaN  1314464           NaN  ...  46429.0  0.168815
#  ...                      ...      ...           ...  ...      ...       ...
#  44472                    NaN  2323367           NaN  ...  30056.0 -0.115007
#  30902                    NaN   415380           NaN  ...  12758.0  0.055230
#  26124                    NaN   165046           NaN  ...  34480.0  0.048132
#  50218                   13.0  1742732           NaN  ...   7915.0  0.164714
#  13140                    NaN  2058934           NaN  ...  12842.0 -0.056061
#
#         transactiondate  airconditioningdesc  architecturalstyledesc  \
#  7727        2017-08-21              Central                    None
#  44139       2017-07-13                 None                    None
#  247         2017-01-06              Central                    None
#  42603       2017-08-25              Central                    None
#  46973       2017-06-14                 None                    None
#  ...                ...                  ...                     ...
#  44472       2017-04-26                 None                    None
#  30902       2017-02-27                 None                    None
#  26124       2017-05-09                 None                    None
#  50218       2017-02-03                  Yes                    None
#  13140       2017-02-27                 None                    None
#
#         buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
#  7727                None           Forced air  Single Family Residential
#  44139               None              Central  Single Family Residential
#  247                 None              Central  Single Family Residential
#  42603               None              Central  Single Family Residential
#  46973               None           Floor/Wall  Single Family Residential
#  ...                  ...                  ...                        ...
#  44472               None                 None  Single Family Residential
#  30902               None                 None  Single Family Residential
#  26124               None                 None  Single Family Residential
#  50218               None                 None  Single Family Residential
#  13140               None                 None  Single Family Residential
#
#        storydesc typeconstructiondesc
#  7727       None                 None
#  44139      None                 None
#  247        None                 None
#  42603      None                 None
#  46973      None                 None
#  ...         ...                  ...
#  44472      None                 None
#  30902      None                 None
#  26124      None                 None
#  50218      None                 None
#  13140      None                 None
#
#  [5575 rows x 69 columns])

# %%
train
# Out:
#        parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 12665  11034859                     NaN          NaN                  261.0
# 21882  12414696                     NaN          NaN                  261.0
# 26080  11922321                     NaN          NaN                  261.0
# 5143   12833180                     NaN          NaN                  261.0
# 23225  12027183                     NaN          NaN                  261.0
# ...         ...                     ...          ...                    ...
# 31979  13009641                     NaN          NaN                  261.0
# 29061  13860688                     NaN          NaN                  261.0
# 26733  11795660                     NaN          NaN                  261.0
# 37761  11450752                     NaN          NaN                  261.0
# 10815  14025543                     NaN          NaN                  261.0
#
#        heatingorsystemtypeid buildingclasstypeid  architecturalstyletypeid  \
# 12665                    7.0                None                       NaN
# 21882                    2.0                None                       NaN
# 26080                    7.0                None                       NaN
# 5143                     7.0                None                       NaN
# 23225                    7.0                None                       NaN
# ...                      ...                 ...                       ...
# 31979                    2.0                None                       NaN
# 29061                    NaN                None                       NaN
# 26733                    2.0                None                       NaN
# 37761                    2.0                None                       NaN
# 10815                    NaN                None                       NaN
#
#        airconditioningtypeid       id  basementsqft  ...       id  logerror  \
# 12665                    NaN  1240408           NaN  ...  37656.0  0.312669
# 21882                    NaN   812926           NaN  ...  75915.0  0.191992
# 26080                    NaN    94865           NaN  ...  49392.0  0.073156
# 5143                     NaN  1694732           NaN  ...  51545.0 -0.044806
# 23225                    NaN   497992           NaN  ...   6839.0  0.743104
# ...                      ...      ...           ...  ...      ...       ...
# 31979                    1.0  2336139           NaN  ...  39387.0 -0.100315
# 29061                    NaN  2873219           NaN  ...  10945.0 -0.046294
# 26733                    1.0  1386532           NaN  ...  21597.0 -0.761094
# 37761                    NaN  1435491           NaN  ...  20734.0  0.149855
# 10815                    NaN   697199           NaN  ...  41779.0  0.437876
#
#        transactiondate  airconditioningdesc  architecturalstyledesc  \
# 12665       2017-05-18                 None                    None
# 21882       2017-09-12                 None                    None
# 26080       2017-06-22                 None                    None
# 5143        2017-06-28                 None                    None
# 23225       2017-01-31                 None                    None
# ...                ...                  ...                     ...
# 31979       2017-05-24              Central                    None
# 29061       2017-02-20                 None                    None
# 26733       2017-03-30              Central                    None
# 37761       2017-03-28                 None                    None
# 10815       2017-05-31                 None                    None
#
#        buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
# 12665               None           Floor/Wall  Single Family Residential
# 21882               None              Central  Single Family Residential
# 26080               None           Floor/Wall  Single Family Residential
# 5143                None           Floor/Wall  Single Family Residential
# 23225               None           Floor/Wall  Single Family Residential
# ...                  ...                  ...                        ...
# 31979               None              Central  Single Family Residential
# 29061               None                 None  Single Family Residential
# 26733               None              Central  Single Family Residential
# 37761               None              Central  Single Family Residential
# 10815               None                 None  Single Family Residential
#
#       storydesc typeconstructiondesc
# 12665      None                 None
# 21882      None                 None
# 26080      None                 None
# 5143       None                 None
# 23225      None                 None
# ...         ...                  ...
# 31979      None                 None
# 29061      None                 None
# 26733      None                 None
# 37761      None                 None
# 10815      None                 None
#
# [15607 rows x 69 columns]

# %% [markdown]
# ## This is big my dataset is now properly split
# ...now what

# %%
train.head()
# Out:
#        parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 12665  11034859                     NaN          NaN                  261.0
# 21882  12414696                     NaN          NaN                  261.0
# 26080  11922321                     NaN          NaN                  261.0
# 5143   12833180                     NaN          NaN                  261.0
# 23225  12027183                     NaN          NaN                  261.0
#
#        heatingorsystemtypeid buildingclasstypeid  architecturalstyletypeid  \
# 12665                    7.0                None                       NaN
# 21882                    2.0                None                       NaN
# 26080                    7.0                None                       NaN
# 5143                     7.0                None                       NaN
# 23225                    7.0                None                       NaN
#
#        airconditioningtypeid       id  basementsqft  ...       id  logerror  \
# 12665                    NaN  1240408           NaN  ...  37656.0  0.312669
# 21882                    NaN   812926           NaN  ...  75915.0  0.191992
# 26080                    NaN    94865           NaN  ...  49392.0  0.073156
# 5143                     NaN  1694732           NaN  ...  51545.0 -0.044806
# 23225                    NaN   497992           NaN  ...   6839.0  0.743104
#
#        transactiondate  airconditioningdesc  architecturalstyledesc  \
# 12665       2017-05-18                 None                    None
# 21882       2017-09-12                 None                    None
# 26080       2017-06-22                 None                    None
# 5143        2017-06-28                 None                    None
# 23225       2017-01-31                 None                    None
#
#        buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
# 12665               None           Floor/Wall  Single Family Residential
# 21882               None              Central  Single Family Residential
# 26080               None           Floor/Wall  Single Family Residential
# 5143                None           Floor/Wall  Single Family Residential
# 23225               None           Floor/Wall  Single Family Residential
#
#       storydesc typeconstructiondesc
# 12665      None                 None
# 21882      None                 None
# 26080      None                 None
# 5143       None                 None
# 23225      None                 None
#
# [5 rows x 69 columns]

# %% [markdown]
# <img src="https://www.reactiongifs.us/wp-content/uploads/2013/06/now_what_finding_nemo.gif">

# %%
#so in looking for some answers the 2.5 error log and up has some super strong outliers that can be dropped
#there are 21 entries that are greater then 2.5 that goes to over 5
#tldr bro this is bombing our accuracy
#now this being said i also need to look at the tope and the bottom
#both pos 2.5 as well as neg 2.5
#ye 2.5 is safe

# %% [markdown]
# ## Explore

# %% [markdown]
# - so here's what finna happen
# - imma go through the previous material cause I have time and do my EDA that way
# - I do not know what to graph or how to graph too well
# - more over practicing these fundamentals will improve my bread and butter basics
# - what i need are questions
# - my train data is not a data frame

# %%
# alright so then first what are some major contributing factors

# %%
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
train.shape
# Out:
# (15607, 69)

# %%
type(validate)
# Out:
# pandas.core.frame.DataFrame

# %%
validate.shape
# Out:
# (6690, 69)

# %%
type(test)
# Out:
# pandas.core.frame.DataFrame

# %%
test.shape
# Out:
# (5575, 69)

# %%
train.isna().sum()
# Out:
# parcelid                      0
# typeconstructiontypeid    15592
# storytypeid               15590
# propertylandusetypeid         0
# heatingorsystemtypeid      4963
#                           ...
# buildingclassdesc         15607
# heatingorsystemdesc        4963
# propertylandusedesc           0
# storydesc                 15590
# typeconstructiondesc      15592
# Length: 69, dtype: int64

# %%
train.shape
# Out:
# (15607, 69)

# %%
#this needs to be applied over in my wrangle setup to even get rid of the columns in my validate and test datasets
def handle_missing_values(df, prop_required_column, prop_required_row):
    n_required_column = round(df.shape[0] * prop_required_column)
    n_required_row = round(df.shape[1] * prop_required_row)
    df = df.dropna(axis=0, thresh=n_required_row)
    df = df.dropna(axis=1, thresh=n_required_column)
    return df

# %%
handle_missing_values(train,prop_required_column=.9,prop_required_row=0)
# Out:
#        parcelid  propertylandusetypeid       id  bathroomcnt  bedroomcnt  \
# 12665  11034859                  261.0  1240408          2.0         3.0
# 21882  12414696                  261.0   812926          2.0         4.0
# 26080  11922321                  261.0    94865          2.0         3.0
# 5143   12833180                  261.0  1694732          3.0         5.0
# 23225  12027183                  261.0   497992          1.0         2.0
# ...         ...                    ...      ...          ...         ...
# 31979  13009641                  261.0  2336139          4.0         4.0
# 29061  13860688                  261.0  2873219          2.5         3.0
# 26733  11795660                  261.0  1386532          3.0         0.0
# 37761  11450752                  261.0  1435491          2.0         3.0
# 10815  14025543                  261.0   697199          2.0         4.0
#
#        calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 12665                2.0                        1280.0                1280.0
# 21882                2.0                        1443.0                1443.0
# 26080                2.0                        1304.0                1304.0
# 5143                 3.0                        1512.0                1512.0
# 23225                1.0                        2033.0                2033.0
# ...                  ...                           ...                   ...
# 31979                4.0                        2356.0                2356.0
# 29061                2.5                        2622.0                2622.0
# 26733                3.0                        2030.0                2030.0
# 37761                2.0                        1198.0                1198.0
# 10815                2.0                        1591.0                1591.0
#
#          fips  fullbathcnt  ...  structuretaxvaluedollarcnt  \
# 12665  6037.0          2.0  ...                     31038.0
# 21882  6037.0          2.0  ...                    125000.0
# 26080  6037.0          2.0  ...                     55701.0
# 5143   6037.0          3.0  ...                    112913.0
# 23225  6037.0          1.0  ...                    388349.0
# ...       ...          ...  ...                         ...
# 31979  6037.0          4.0  ...                    370793.0
# 29061  6059.0          2.0  ...                    325785.0
# 26733  6037.0          3.0  ...                    243703.0
# 37761  6037.0          2.0  ...                     36634.0
# 10815  6059.0          2.0  ...                     58602.0
#
#        taxvaluedollarcnt  assessmentyear landtaxvaluedollarcnt  taxamount  \
# 12665            58348.0          2016.0               27310.0     919.07
# 21882           628000.0          2016.0              503000.0    7138.50
# 26080           278328.0          2016.0              222627.0    3461.43
# 5143            345429.0          2016.0              232516.0    4219.63
# 23225          1941761.0          2016.0             1553412.0   23498.40
# ...                  ...             ...                   ...        ...
# 31979           958153.0          2016.0              587360.0   11044.83
# 29061          1151799.0          2016.0              826014.0   12803.06
# 26733           304603.0          2016.0               60900.0    5836.18
# 37761            82589.0          2016.0               45955.0    1191.99
# 10815            86914.0          2016.0               28312.0    1491.02
#
#        censustractandblock       id  logerror  transactiondate  \
# 12665         6.037119e+13  37656.0  0.312669       2017-05-18
# 21882         4.830301e+14  75915.0  0.191992       2017-09-12
# 26080         6.037463e+13  49392.0  0.073156       2017-06-22
# 5143          6.037409e+13  51545.0 -0.044806       2017-06-28
# 23225         6.037194e+13   6839.0  0.743104       2017-01-31
# ...                    ...      ...       ...              ...
# 31979         6.037432e+13  39387.0 -0.100315       2017-05-24
# 29061         6.059099e+13  10945.0 -0.046294       2017-02-20
# 26733         6.037206e+13  21597.0 -0.761094       2017-03-30
# 37761         6.037650e+13  20734.0  0.149855       2017-03-28
# 10815         6.059064e+13  41779.0  0.437876       2017-05-31
#
#              propertylandusedesc
# 12665  Single Family Residential
# 21882  Single Family Residential
# 26080  Single Family Residential
# 5143   Single Family Residential
# 23225  Single Family Residential
# ...                          ...
# 31979  Single Family Residential
# 29061  Single Family Residential
# 26733  Single Family Residential
# 37761  Single Family Residential
# 10815  Single Family Residential
#
# [15607 rows x 30 columns]

# %% [markdown]
# I have dropped over 60 columns that had 90% of their entries empty. Now what?
# We can start graphing stuff, possibly build out graphs to start seeing some of those relationships if there are any.

# %%
train.columns
#it would be most prudent to be able to read off what this stuff means
# Out:
# Index(['parcelid', 'typeconstructiontypeid', 'storytypeid',
#        'propertylandusetypeid', 'heatingorsystemtypeid', 'buildingclasstypeid',
#        'architecturalstyletypeid', 'airconditioningtypeid', 'id',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid',
#        'calculatedbathnbr', 'decktypeid', 'finishedfloor1squarefeet',
#        'calculatedfinishedsquarefeet', 'finishedsquarefeet12',
#        'finishedsquarefeet13', 'finishedsquarefeet15', 'finishedsquarefeet50',
#        'finishedsquarefeet6', 'fips', 'fireplacecnt', 'fullbathcnt',
#        'garagecarcnt', 'garagetotalsqft', 'hashottuborspa', 'latitude',
#        'longitude', 'lotsizesquarefeet', 'poolcnt', 'poolsizesum',
#        'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertycountylandusecode', 'propertyzoningdesc',
#        'rawcensustractandblock', 'regionidcity', 'regionidcounty',
#        'regionidneighborhood', 'regionidzip', 'roomcnt', 'threequarterbathnbr',
#        'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
#        'numberofstories', 'fireplaceflag', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
#        'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear',
#        'censustractandblock', 'id', 'logerror', 'transactiondate',
#        'airconditioningdesc', 'architecturalstyledesc', 'buildingclassdesc',
#        'heatingorsystemdesc', 'propertylandusedesc', 'storydesc',
#        'typeconstructiondesc'],
#       dtype='object')

# %% [markdown]
# typeconstructiontypeid - the material used in the building process
# storytypeid - the amount of floors the building has
# propertylandusetypeid -

# %% [markdown]
# picking up where i left off I'm am going to have make adjustments with how the information is currently being handled
#
# This means i gotta find where i went wrong and then adjust from there
# ## Explore

# %%
#dropping off columns that are 90% empty
df = acquire.handle_missing_values(df,prop_required_column=.9,prop_required_row=0)

# %%
df = acquire.takeout_outliers1(df)

# %%
df.head()
# Out:
#    parcelid  propertylandusetypeid     id  bathroomcnt  bedroomcnt  \
# 0  17173851                  261.0    787          2.0         4.0
# 3  11457850                  261.0   3770          2.0         3.0
# 5  12755884                  261.0   8864          1.0         3.0
# 6  13983750                  261.0  10930          1.5         2.0
# 8  14399561                  261.0  12462          3.0         4.0
#
#    calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                2.0                        1848.0                1848.0
# 3                2.0                        1412.0                1412.0
# 5                1.0                         900.0                 900.0
# 6                1.5                        1213.0                1213.0
# 8                3.0                        2834.0                2834.0
#
#      fips  fullbathcnt  ...  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 0  6111.0          2.0  ...                     47193.0            64712.0
# 3  6037.0          2.0  ...                     38700.0            93146.0
# 5  6037.0          1.0  ...                     51376.0           101313.0
# 6  6059.0          1.0  ...                     47458.0           431697.0
# 8  6059.0          3.0  ...                    398523.0           943142.0
#
#    assessmentyear landtaxvaluedollarcnt  taxamount  censustractandblock  \
# 0          2016.0               17519.0     781.00         6.111004e+13
# 3          2016.0               54446.0    1246.18         6.037276e+13
# 5          2016.0               49937.0    1606.54         6.037553e+13
# 6          2016.0              384239.0    5451.26         6.059042e+13
# 8          2016.0              544619.0    9482.12         6.059063e+13
#
#        id  logerror  transactiondate        propertylandusedesc
# 0   389.0  0.088469       2017-01-03  Single Family Residential
# 3  2229.0  0.054233       2017-01-11  Single Family Residential
# 5  1192.0  0.442837       2017-01-06  Single Family Residential
# 6  3247.0  0.087099       2017-01-17  Single Family Residential
# 8  2883.0  0.032578       2017-01-13  Single Family Residential
#
# [5 rows x 30 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# So now the og database has its outliers handled across the board
#
# Ready to split

# %%
train, validate, test = acquire.traintestsplit(df)

# %%
train.shape
# Out:
# (15598, 30)

# %%
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
validate.shape
# Out:
# (6685, 30)

# %%
type(validate)
# Out:
# pandas.core.frame.DataFrame

# %%
test.shape
# Out:
# (5571, 30)

# %%
type(test)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# the data is split and looking healthy

# %%
train_scaled, validate_scaled, test_scaled = acquire.splitmoreways(train, validate, test)

# %%
#ValueError: Columns must be same length as key
#current assumption on this error is that i have all of the columns being called except for my target variable

#same error as before adding in missing value

# %% [markdown]
# I have dropped off features that are categorical values. These mean close tp nothing to my ML models. Since ML models do best on spectrums of data rather then definite types

# %%
train_scaled.head()
# Out:
#        parcelid  propertylandusetypeid       id  bathroomcnt  bedroomcnt  \
# 40731  11201787                    0.0  1076702     0.090909         0.3
# 1059   12742740                    0.0  1171903     0.090909         0.3
# 48642  14139824                    0.0  1547881     0.181818         0.4
# 42603  11284938                    0.0  1733607     0.181818         0.3
# 17181  10959322                    0.0   792630     0.181818         0.3
#
#        calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 40731                0.0                      0.043266              0.043266
# 1059                 0.0                      0.040790              0.040790
# 48642                0.1                      0.064545              0.064545
# 42603                0.1                      0.072149              0.072149
# 17181                0.1                      0.072149              0.072149
#
#          fips  fullbathcnt  ...  structuretaxvaluedollarcnt  \
# 40731  6037.0          0.0  ...                    0.012987
# 1059   6037.0          0.0  ...                    0.008059
# 48642  6059.0          0.1  ...                    0.005657
# 42603  6037.0          0.1  ...                    0.018651
# 17181  6037.0          0.1  ...                    0.023557
#
#        taxvaluedollarcnt  assessmentyear landtaxvaluedollarcnt  taxamount  \
# 40731           0.004681             0.0              0.001028   0.007367
# 1059            0.011687             0.0              0.010616   0.013064
# 48642           0.002649             0.0              0.001138   0.003517
# 42603           0.006737             0.0              0.001495   0.009498
# 17181           0.018642             0.0              0.013405   0.017714
#
#        censustractandblock       id  logerror  transactiondate  \
# 40731             0.000019  35109.0 -0.048415       2017-05-11
# 1059              0.000011    821.0  0.171315       2017-01-05
# 48642             0.000518  27473.0  0.066977       2017-04-18
# 42603             0.000019  70368.0  0.037205       2017-08-25
# 17181             0.000005  68119.0  0.037416       2017-08-18
#
#              propertylandusedesc
# 40731  Single Family Residential
# 1059   Single Family Residential
# 48642  Single Family Residential
# 42603  Single Family Residential
# 17181  Single Family Residential
#
# [5 rows x 30 columns]

# %% [markdown]
# Well it seems that this error auto-magically fixed itself after a kernel

# %% [markdown]
# Now what? I'm not entirely sure here.
# Uhhhhhhhhhhhhhh ummmmmmmm
#
# The presentations they are giving don't involve me
# It really ain't doing a damn thing for me
# I am entertaining others by doing this

# %%
#let's build small graphs

# %%
sns.boxplot(y=train.logerror, data=train)
#wtf is going on here
#it is telling me that there is a low hanging outlier (-4) that may skew my data
#it is also telling me that there is a heavy positive outlier (4)
#even though I have scaled my data I can go back and re-edit my outliers
#x=train.bathroomcnt,
# Out:
# <AxesSubplot:ylabel='logerror'>

# %%
train.logerror.describe()
# Out:
# count    15598.000000
# mean         0.032996
# std          0.231020
# min         -2.406257
# 25%         -0.053620
# 50%          0.037586
# 75%          0.079135
# max          2.479045
# Name: logerror, dtype: float64

# %% [markdown]
# ![Screenshot%202022-06-15%20at%2011-16-31%20explore_zillow%20-%20Jupyter%20Notebook.png](attachment:Screenshot%202022-06-15%20at%2011-16-31%20explore_zillow%20-%20Jupyter%20Notebook.png)

# %% [markdown]
# The above reading tells me that I have not handled the upper outliers as much as I thought

# %%
#IT WORKS AS INTENDED FINALLY....only took like 30 minutes to fix

# %%
# wait now what? i can continue exploring to see where i find models
sns.barplot(x=train.bathroomcnt, y=train.logerror)
#what in good god happened at the 8.5 bath
# Out:
# <AxesSubplot:xlabel='bathroomcnt', ylabel='logerror'>

# %% [markdown]
# ### What is the relationship between error rate and bathroom count?

# %%
# only need like 3 or 4 exploring techniques to be able to deliver an MVP
sns.scatterplot(x=train.bathroomcnt, y=train.logerror)
#this here tells us that there is a little more inaccuracy around 1-5 bathrooms
# Out:
# <AxesSubplot:xlabel='bathroomcnt', ylabel='logerror'>

# %% [markdown]
# - takeaway: there is a larger range of error between 1 and 5 bathrooms

# %% [markdown]
# <img src="https://c.tenor.com/gQV5VzHLWQIAAAAd/among-us-sus.gif" width="12">

# %%
sns.histplot(x=train.logerror)
#nope not a thing
#x=train.bathroomcnt,
#not gong lie this one look kinda cool
#YO THIS ALSO ANSWERS THAT WHILE ON A MACRO SCALE THE ERRORS ERR TOWARDS NEGATIVE THE ONES THAT COUNT WERE MORE IN THE POSITIVES
# Out:
# <AxesSubplot:xlabel='logerror', ylabel='Count'>

# %%
train.columns
# Out:
# Index(['parcelid', 'propertylandusetypeid', 'id', 'bathroomcnt', 'bedroomcnt',
#        'calculatedbathnbr', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'fips', 'fullbathcnt', 'latitude', 'longitude',
#        'lotsizesquarefeet', 'propertycountylandusecode',
#        'rawcensustractandblock', 'regionidcity', 'regionidcounty',
#        'regionidzip', 'roomcnt', 'yearbuilt', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
#        'taxamount', 'censustractandblock', 'id', 'logerror', 'transactiondate',
#        'propertylandusedesc'],
#       dtype='object')

# %% [markdown]
# <b>If feature on here but not in list above drop below</b>
# 'propertylandusetypeid', 'bathroomcnt', 'bedroomcnt',
#        'calculatedbathnbr', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'fullbathcnt', 'latitude', 'longitude',
#        'lotsizesquarefeet', 'rawcensustractandblock',
#         'roomcnt', 'yearbuilt',
#        'structuretaxvaluedollarcnt', 'taxvaluedollarcnt', 'assessmentyear',
#        'landtaxvaluedollarcnt', 'taxamount', 'censustractandblock'

# %%
train.drop(columns=["parcelid","id","fips",
                    "propertycountylandusecode",
                    "regionidcity","regionidzip","transactiondate","propertylandusedesc","regionidcounty",
                   "assessmentyear"])
# Out:
#        propertylandusetypeid  bathroomcnt  bedroomcnt  calculatedbathnbr  \
# 40731                  261.0          1.0         3.0                1.0
# 1059                   261.0          1.0         3.0                1.0
# 48642                  261.0          2.0         4.0                2.0
# 42603                  261.0          2.0         3.0                2.0
# 17181                  261.0          2.0         3.0                2.0
# ...                      ...          ...         ...                ...
# 39497                  261.0          1.0         2.0                1.0
# 22243                  261.0          1.0         4.0                1.0
# 5965                   261.0          3.0         3.0                3.0
# 51844                  261.0          3.0         4.0                3.0
# 21684                  261.0          2.0         3.0                2.0
#
#        calculatedfinishedsquarefeet  finishedsquarefeet12  fullbathcnt  \
# 40731                        1014.0                1014.0          1.0
# 1059                          972.0                 972.0          1.0
# 48642                        1375.0                1375.0          2.0
# 42603                        1504.0                1504.0          2.0
# 17181                        1504.0                1504.0          2.0
# ...                             ...                   ...          ...
# 39497                        1696.0                1696.0          1.0
# 22243                        1011.0                1011.0          1.0
# 5965                         2370.0                2370.0          3.0
# 51844                        2302.0                2302.0          3.0
# 21684                        1325.0                1325.0          2.0
#
#          latitude    longitude  lotsizesquarefeet  rawcensustractandblock  \
# 40731  34582036.0 -118098837.0             6560.0            6.037911e+07
# 1059   33910039.0 -118064750.0             6196.0            6.037552e+07
# 48642  33903910.0 -117894029.0             9672.0            6.059002e+07
# 42603  34681971.0 -118140788.0             7194.0            6.037901e+07
# 17181  34161832.0 -118349956.0             6667.0            6.037311e+07
# ...           ...          ...                ...                     ...
# 39497  34148774.0 -117861500.0            68460.0            6.037401e+07
# 22243  33957673.0 -118257969.0             5157.0            6.037240e+07
# 5965   34557122.0 -118055754.0             7004.0            6.037911e+07
# 51844  34227488.0 -118522387.0             6075.0            6.037115e+07
# 21684  34057710.0 -117909919.0             8915.0            6.037407e+07
#
#        roomcnt  yearbuilt  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 40731      0.0     1953.0                     95839.0           119798.0
# 1059       0.0     1950.0                     59523.0           297619.0
# 48642      7.0     1963.0                     41818.0            68237.0
# 42603      0.0     1980.0                    137585.0           171979.0
# 17181      0.0     1941.0                    173744.0           474143.0
# ...        ...        ...                         ...                ...
# 39497      0.0     1947.0                    223355.0          1116775.0
# 22243      0.0     1937.0                    123163.0           235091.0
# 5965       0.0     1991.0                    123079.0           153848.0
# 51844      0.0     1979.0                    237173.0           514914.0
# 21684      0.0     1952.0                    127375.0           364875.0
#
#        landtaxvaluedollarcnt  taxamount  censustractandblock  logerror
# 40731                23959.0    2205.67         6.037911e+13 -0.048415
# 1059                238096.0    3863.36         6.037552e+13  0.171315
# 48642                26419.0    1085.52         6.059002e+13  0.066977
# 42603                34394.0    2825.66         6.037901e+13  0.037205
# 17181               300399.0    5216.03         6.037311e+13  0.037416
# ...                      ...        ...                  ...       ...
# 39497               893420.0   12526.66         6.037401e+13  0.081726
# 22243               111928.0    3049.57         6.037240e+13 -0.084951
# 5965                 30769.0    3792.13         6.037911e+13  0.678761
# 51844               277741.0    6342.20         6.037115e+13 -0.079843
# 21684               237500.0    4239.53         6.037407e+13  0.041462
#
# [15598 rows x 19 columns]

# %%
train.bedroomcnt.value_counts()
# Out:
# 3.0     6679
# 4.0     4298
# 2.0     2796
# 5.0     1244
# 6.0      246
# 1.0      225
# 0.0       51
# 7.0       40
# 8.0       14
# 9.0        4
# 10.0       1
# Name: bedroomcnt, dtype: int64
