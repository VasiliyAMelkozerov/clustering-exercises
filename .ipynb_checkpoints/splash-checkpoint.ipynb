# %%
import pandas as pd
import seaborn as sns
import acquire
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from sklearn.cluster import KMeans
from sklearn.feature_selection import SelectKBest, f_regression

# %%
df = acquire.zillow_data()
df
# Out:
#        parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 0      17173851                     NaN          NaN                  261.0
# 1      10821119                     NaN          NaN                  261.0
# 2      11007640                     NaN          NaN                  261.0
# 3      11457850                     NaN          NaN                  261.0
# 4      12591550                     NaN          NaN                  261.0
# ...         ...                     ...          ...                    ...
# 52437  12885754                     NaN          NaN                  261.0
# 52438  13869000                     NaN          NaN                  261.0
# 52439  13890509                     NaN          NaN                  261.0
# 52440  17246810                     NaN          NaN                  261.0
# 52441  14360869                     NaN          NaN                  261.0
#
# ...

# %%
#so from here I dropped tons of columns
df.isnull().sum()
# Out:
# parcelid                      0
# typeconstructiontypeid    52366
# storytypeid               52395
# propertylandusetypeid         0
# heatingorsystemtypeid     18507
#                           ...
# buildingclassdesc         52442
# heatingorsystemdesc       18507
# propertylandusedesc           0
# storydesc                 52395
# typeconstructiondesc      52366
# Length: 69, dtype: int64

# %%
df = acquire.handle_missing_values(df,prop_required_column=.9,prop_required_row=0)
df
#my whole ham dataframe now has columns dropped that are 90% nulls
# Out:
#        parcelid  propertylandusetypeid       id  bathroomcnt  bedroomcnt  \
# 0      17173851                  261.0      787          2.0         4.0
# 1      10821119                  261.0     1702          2.0         2.0
# 2      11007640                  261.0     2412          2.0         3.0
# 3      11457850                  261.0     3770          2.0         3.0
# 4      12591550                  261.0     8197          2.0         3.0
# ...         ...                    ...      ...          ...         ...
# 52437  12885754                  261.0  2976765          1.0         3.0
# 52438  13869000                  261.0  2977815          2.0         4.0
# 52439  13890509                  261.0  2977914          4.0         3.0
# 52440  17246810                  261.0  2980979          2.5         3.0
# 52441  14360869                  261.0  2982193          3.5         4.0
#
#        calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# ...

# %%
#while many of those columns may contain useful information they do not aid in building out an MVP
df.isnull().sum()
# Out:
# parcelid                           0
# propertylandusetypeid              0
# id                                 0
# bathroomcnt                        0
# bedroomcnt                         0
# calculatedbathnbr                138
# calculatedfinishedsquarefeet      83
# finishedsquarefeet12             248
# fips                               0
# fullbathcnt                      138
# latitude                           0
# longitude                          0
# lotsizesquarefeet                369
# propertycountylandusecode          0
# rawcensustractandblock             0
# regionidcity                    1037
# regionidcounty                     0
# regionidzip                       26
# roomcnt                            0
# yearbuilt                        117
# structuretaxvaluedollarcnt        85
# taxvaluedollarcnt                  1
# assessmentyear                     0
# landtaxvaluedollarcnt              1
# taxamount                          4
# ...

# %% [markdown]
# # This is enormous I have cut my dataset in HALF!!!!!!!
# > - 52442 rows
# > - 27854 rows

# %%
df = acquire.takeout_outliers1(df)
df
# Out:
#        parcelid  propertylandusetypeid       id  bathroomcnt  bedroomcnt  \
# 0      17173851                  261.0      787          2.0         4.0
# 3      11457850                  261.0     3770          2.0         3.0
# 5      12755884                  261.0     8864          1.0         3.0
# 6      13983750                  261.0    10930          1.5         2.0
# 8      14399561                  261.0    12462          3.0         4.0
# ...         ...                    ...      ...          ...         ...
# 52436  12087743                  261.0  2973484          1.0         3.0
# 52437  12885754                  261.0  2976765          1.0         3.0
# 52439  13890509                  261.0  2977914          4.0         3.0
# 52440  17246810                  261.0  2980979          2.5         3.0
# 52441  14360869                  261.0  2982193          3.5         4.0
#
#        calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# ...

# %%
df.isnull().sum().sum()
# Out:
# 1392

# %%
1392 / 27854
#we lose about 5% of our data when dropping nulls
#I can also fill in all of the nulls with 0s and keep as much of the data intact as possible
#ye let's do that
# Out:
# 0.049974868959574925

# %%
#let's tresure this 5% and keep it 
#instead of dropping it i am simply going to fill in with a working 0 value
#the rest of the columns should be considered
#5% does not seem like much but when I have lopped this dataframe in half I gotta kepp whatever I can get
df.fillna(0)
df.isnull().sum()
# Out:
# parcelid                          0
# propertylandusetypeid             0
# id                                0
# bathroomcnt                       0
# bedroomcnt                        0
# calculatedbathnbr               100
# calculatedfinishedsquarefeet     56
# finishedsquarefeet12            187
# fips                              0
# fullbathcnt                     100
# latitude                          0
# longitude                         0
# lotsizesquarefeet               212
# propertycountylandusecode         0
# rawcensustractandblock            0
# regionidcity                    495
# regionidcounty                    0
# regionidzip                      19
# roomcnt                           0
# yearbuilt                        79
# structuretaxvaluedollarcnt       67
# taxvaluedollarcnt                 1
# assessmentyear                    0
# landtaxvaluedollarcnt             1
# taxamount                         4
# censustractandblock              71
# ...

# %%
df = df.fillna(0)
df.shape
# Out:
# (27854, 30)

# %%
df.dropna().shape
# df.shape
# df.isnull().sum()
# Out:
# (27854, 30)

# %%
#this is so that I can recreate my cluster in a smaller notebook

# %% [markdown]
# I think I just noticed a gigantic mistake I have made, none of these items are applied in the wrangle method

# %%
#what should happen in the code is that i bring in my adjusted dataframe into the train test split function

# %%
#so what it should safe is 
train, validate, test = acquire.traintestsplit(df)
train, validate, test
#where df gives you null and value adjusted
# Out:
# (       parcelid  propertylandusetypeid       id  bathroomcnt  bedroomcnt  \
#  40731  11201787                  261.0  1076702          1.0         3.0
#  1059   12742740                  261.0  1171903          1.0         3.0
#  48642  14139824                  261.0  1547881          2.0         4.0
#  42603  11284938                  261.0  1733607          2.0         3.0
#  17181  10959322                  261.0   792630          2.0         3.0
#  ...         ...                    ...      ...          ...         ...
#  39497  13031951                  261.0  1770092          1.0         2.0
#  22243  12212883                  261.0  1483089          1.0         4.0
#  5965   11236523                  261.0   256768          3.0         3.0
#  51844  11102412                  261.0  1852409          3.0         4.0
#  21684  12952021                  261.0   427390          2.0         3.0
#
#         calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# ...

# %%
type(train)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# so from here need to adjust need to acquire my df

# %%
# train, validate, test = acquire.traintestsplit(outlies)
# #the mistake is that my models have been fed incomplete information
# train, validate, test

# %%
#label what we want clustered
X = train[["logerror"]]
#get the thing
kmeans = KMeans(n_clusters=5)
#fit the thing
kmeans.fit(X)
#run the thing
print(kmeans.predict(X))
#make new column named cluster that holds their clustere value group 0-4
train['cluster'] = kmeans.predict(X)
# Out:
# [3 0 0 ... 4 3 0]

# %%
#label what we want clustered
X = train[["longitude","latitude"]]
#get the thing
kmeans = KMeans(n_clusters=5)
#fit the thing
kmeans.fit(X)
#run the thing
print(kmeans.predict(X))
#make new column named cluster that holds their clustere value group 0-4
train['zones'] = kmeans.predict(X)
# Out:
# [2 1 1 ... 2 0 1]

# %% [markdown]
# What I need to look up and understand is how I can make these into their own columns, alias them first maybe

# %%
#wow okay it  even splits up the map to how many clusters I want
sns.scatterplot(x=train.latitude,y=train.longitude, hue=train.cluster, palette="deep")
#not very helpful to current scope/range but nice to look at
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# Ignore the above clustering from here I should bring in my top 5

# %%
train_scaled, validate_scaled, test_scaled = acquire.drop_cat_columns(train, validate, test)
train_scaled, validate_scaled, test_scaled
#so now that this functions work then what?
# Out:
# (       propertylandusetypeid  bathroomcnt  bedroomcnt  calculatedbathnbr  \
#  40731                  261.0          1.0         3.0                1.0
#  1059                   261.0          1.0         3.0                1.0
#  48642                  261.0          2.0         4.0                2.0
#  42603                  261.0          2.0         3.0                2.0
#  17181                  261.0          2.0         3.0                2.0
#  ...                      ...          ...         ...                ...
#  39497                  261.0          1.0         2.0                1.0
#  22243                  261.0          1.0         4.0                1.0
#  5965                   261.0          3.0         3.0                3.0
#  51844                  261.0          3.0         4.0                3.0
#  21684                  261.0          2.0         3.0                2.0
#
#         calculatedfinishedsquarefeet  finishedsquarefeet12  fullbathcnt  \
# ...

# %%
train_scaled, validate_scaled, test_scaled = acquire.splitmoreways(train, validate, test)

# %%
train_scaled = train_scaled.drop(columns=["parcelid","id","fips",
                    "propertycountylandusecode",
                    "regionidcity","regionidzip","transactiondate","propertylandusedesc","regionidcounty",
                   "assessmentyear"])
train_scaled.columns
# Out:
# Index(['propertylandusetypeid', 'bathroomcnt', 'bedroomcnt',
#        'calculatedbathnbr', 'calculatedfinishedsquarefeet',
#        'finishedsquarefeet12', 'fullbathcnt', 'latitude', 'longitude',
#        'lotsizesquarefeet', 'rawcensustractandblock', 'roomcnt', 'yearbuilt',
#        'structuretaxvaluedollarcnt', 'taxvaluedollarcnt',
#        'landtaxvaluedollarcnt', 'taxamount', 'censustractandblock', 'logerror',
#        'cluster'],
#       dtype='object')

# %%
train_scaled[train_scaled.eq("010G").any(1)]
# Out:
# Empty DataFrame
# Columns: [propertylandusetypeid, bathroomcnt, bedroomcnt, calculatedbathnbr, calculatedfinishedsquarefeet, finishedsquarefeet12, fullbathcnt, latitude, longitude, lotsizesquarefeet, rawcensustractandblock, roomcnt, yearbuilt, structuretaxvaluedollarcnt, taxvaluedollarcnt, landtaxvaluedollarcnt, taxamount, censustractandblock, logerror, cluster]
# Index: []

# %%
#as in bring in the select k-best
# np.seterr(divide='ignore', invalid='ignore')
# parameters: f_regression stats test, give me 13 features
f_selector = SelectKBest(f_regression, k=19)

# find the top 8 X's correlated with y
f_selector.fit(train_scaled, train.logerror)

# boolean mask of whether the column was selected or not. 
feature_mask = f_selector.get_support()

# get list of top K features. 
f_feature = train_scaled.iloc[:,feature_mask].columns.tolist()

f_feature
#these features alos are great drivers for taxvaluedolarcnt which is then used in the zestimate
# Out:
# /usr/local/anaconda3/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py:302: RuntimeWarning: invalid value encountered in true_divide
#   corr /= X_norms
# ['bathroomcnt',
#  'bedroomcnt',
#  'calculatedbathnbr',
#  'calculatedfinishedsquarefeet',
#  'finishedsquarefeet12',
#  'fullbathcnt',
#  'latitude',
#  'longitude',
#  'lotsizesquarefeet',
#  'rawcensustractandblock',
#  'roomcnt',
#  'yearbuilt',
#  'structuretaxvaluedollarcnt',
#  'taxvaluedollarcnt',
#  'landtaxvaluedollarcnt',
#  'taxamount',
#  'censustractandblock',
#  'logerror',
#  'cluster']

# %%
sns.scatterplot(x=train_scaled.latitude,y=train_scaled.longitude, hue=train_scaled.cluster)
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='longitude'>
