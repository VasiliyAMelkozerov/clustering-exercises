# %%
import pandas as pd
import seaborn as sns
import acquire

# %% [markdown]
# ## Acquire and Summarize

# %% [markdown]
# 1. Acquire data from the cloud database.
#
#     You will want to end with a single dataframe. Include the logerror field and all other fields related to the properties that are available. You will end up using all the tables in the database.
#
#     <b><i>Be sure to do the correct join (inner, outer, etc.). We do not want to eliminate properties purely because they may have a null value for airconditioningtypeid.</i></b> - Only include properties with a transaction in 2017, and include only the last transaction for each property (so no duplicate property ID's), along with zestimate error and date of transaction. (Hint: read the docs for the .duplicated method) - Only include properties that have a latitude and longitude value.
#
#
# 2. Summarize your data (summary stats, info, dtypes, shape, distributions, value_counts, etc.)
#
#
# 3. Write a function that takes in a dataframe of observations and attributes and returns a dataframe where each row is an atttribute name, the first column is the number of rows with missing values for that attribute, and the second column is percent of total rows that have missing values for that attribute. Run the function and document takeaways from this on how you want to handle missing values.

# %%
df = acquire.zillow_data()
df
# Out:
#          parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 0        17173851                     NaN          NaN                  261.0
# 1        10821119                     NaN          NaN                  261.0
# 2        11007640                     NaN          NaN                  261.0
# 3        11457850                     NaN          NaN                  261.0
# 4        12591550                     NaN          NaN                  261.0
# ...           ...                     ...          ...                    ...
# 2152981  13915341                     NaN          NaN                  261.0
# 2152982  14360869                     NaN          NaN                  261.0
# 2152983  13952473                     NaN          NaN                  261.0
# 2152984  14367624                     NaN          NaN                  261.0
# 2152985  12385768                     NaN          NaN                  261.0
#
#          heatingorsystemtypeid  buildingclasstypeid  architecturalstyletypeid  \
# 0                          NaN                  NaN                       NaN
# 1                          2.0                  NaN                       NaN
# 2                          2.0                  NaN                       NaN
# 3                          7.0                  NaN                       NaN
# 4                          2.0                  NaN                       NaN
# ...                        ...                  ...                       ...
# 2152981                    NaN                  NaN                       NaN
# 2152982                    NaN                  NaN                       NaN
# 2152983                    NaN                  NaN                       NaN
# 2152984                    NaN                  NaN                       NaN
# 2152985                    2.0                  NaN                       NaN
#
#          airconditioningtypeid       id  basementsqft  ...       id  logerror  \
# 0                          NaN      787           NaN  ...    389.0  0.088469
# 1                          NaN     1702           NaN  ...    402.0  0.025629
# 2                          1.0     2412           NaN  ...   2699.0  0.020360
# 3                          NaN     3770           NaN  ...   2229.0  0.054233
# 4                          NaN     8197           NaN  ...   3038.0 -0.016170
# ...                        ...      ...           ...  ...      ...       ...
# 2152981                    NaN  2982148           NaN  ...      NaN       NaN
# 2152982                    NaN  2982193           NaN  ...  71174.0  0.086432
# 2152983                    NaN  2982226           NaN  ...      NaN       NaN
# 2152984                    NaN  2982275           NaN  ...      NaN       NaN
# 2152985                    1.0  2982282           NaN  ...      NaN       NaN
#
#          transactiondate  airconditioningdesc  architecturalstyledesc  \
# 0             2017-01-03                 None                    None
# 1             2017-01-03                 None                    None
# 2             2017-01-12              Central                    None
# 3             2017-01-11                 None                    None
# 4             2017-01-13                 None                    None
# ...                  ...                  ...                     ...
# 2152981             None                 None                    None
# 2152982       2017-08-29                 None                    None
# 2152983             None                 None                    None
# 2152984             None                 None                    None
# 2152985             None              Central                    None
#
#          buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
# 0                     None                 None  Single Family Residential
# 1                     None              Central  Single Family Residential
# 2                     None              Central  Single Family Residential
# 3                     None           Floor/Wall  Single Family Residential
# 4                     None              Central  Single Family Residential
# ...                    ...                  ...                        ...
# 2152981               None                 None  Single Family Residential
# 2152982               None                 None  Single Family Residential
# 2152983               None                 None  Single Family Residential
# 2152984               None                 None  Single Family Residential
# 2152985               None              Central  Single Family Residential
#
#          storydesc  typeconstructiondesc
# 0             None                  None
# 1             None                  None
# 2             None                  None
# 3             None                  None
# 4             None                  None
# ...            ...                   ...
# 2152981       None                  None
# 2152982       None                  None
# 2152983       None                  None
# 2152984       None                  None
# 2152985       None                  None
#
# [2152986 rows x 69 columns]

# %%
df.shape
# Out:
# (2152986, 69)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2152986 entries, 0 to 2152985
# Data columns (total 69 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   parcelid                      int64
#  1   typeconstructiontypeid        float64
#  2   storytypeid                   float64
#  3   propertylandusetypeid         float64
#  4   heatingorsystemtypeid         float64
#  5   buildingclasstypeid           float64
#  6   architecturalstyletypeid      float64
#  7   airconditioningtypeid         float64
#  8   id                            int64
#  9   basementsqft                  float64
#  10  bathroomcnt                   float64
#  11  bedroomcnt                    float64
#  12  buildingqualitytypeid         float64
#  13  calculatedbathnbr             float64
#  14  decktypeid                    float64
#  15  finishedfloor1squarefeet      float64
#  16  calculatedfinishedsquarefeet  float64
#  17  finishedsquarefeet12          float64
#  18  finishedsquarefeet13          float64
#  19  finishedsquarefeet15          float64
#  20  finishedsquarefeet50          float64
#  21  finishedsquarefeet6           float64
#  22  fips                          float64
#  23  fireplacecnt                  float64
#  24  fullbathcnt                   float64
#  25  garagecarcnt                  float64
#  26  garagetotalsqft               float64
#  27  hashottuborspa                float64
#  28  latitude                      float64
#  29  longitude                     float64
#  30  lotsizesquarefeet             float64
#  31  poolcnt                       float64
#  32  poolsizesum                   float64
#  33  pooltypeid10                  float64
#  34  pooltypeid2                   float64
#  35  pooltypeid7                   float64
#  36  propertycountylandusecode     object
#  37  propertyzoningdesc            object
#  38  rawcensustractandblock        float64
#  39  regionidcity                  float64
#  40  regionidcounty                float64
#  41  regionidneighborhood          float64
#  42  regionidzip                   float64
#  43  roomcnt                       float64
#  44  threequarterbathnbr           float64
#  45  unitcnt                       float64
#  46  yardbuildingsqft17            float64
#  47  yardbuildingsqft26            float64
#  48  yearbuilt                     float64
#  49  numberofstories               float64
#  50  fireplaceflag                 float64
#  51  structuretaxvaluedollarcnt    float64
#  52  taxvaluedollarcnt             float64
#  53  assessmentyear                float64
#  54  landtaxvaluedollarcnt         float64
#  55  taxamount                     float64
#  56  taxdelinquencyflag            object
#  57  taxdelinquencyyear            float64
#  58  censustractandblock           float64
#  59  id                            float64
#  60  logerror                      float64
#  61  transactiondate               object
#  62  airconditioningdesc           object
#  63  architecturalstyledesc        object
#  64  buildingclassdesc             object
#  65  heatingorsystemdesc           object
#  66  propertylandusedesc           object
#  67  storydesc                     object
#  68  typeconstructiondesc          object
# dtypes: float64(56), int64(2), object(11)
# memory usage: 1.1+ GB

# %%
df.describe().T
# Out:
#                                   count          mean           std  \
# parcelid                      2152986.0  1.309662e+07  5.172433e+06
# typeconstructiontypeid           2658.0  5.981189e+00  3.486948e-01
# storytypeid                      1535.0  7.000000e+00  0.000000e+00
# propertylandusetypeid         2152986.0  2.610000e+02  1.226738e-02
nt                       1.000000e+00  1.000000e+00  1.000000e+00
# yardbuildingsqft17            1.000000e+01  2.000000e+02  2.880000e+02
# yardbuildingsqft26            1.000000e+01  1.000000e+02  1.680000e+02
# yearbuilt                     1.801000e+03  1.949000e+03  1.958000e+03
# numberofstories               1.000000e+00  1.000000e+00  1.000000e+00
# fireplaceflag                 1.000000e+00  1.000000e+00  1.000000e+00
# structuretaxvaluedollarcnt    1.000000e+00  7.414000e+04  1.224390e+05
# taxvaluedollarcnt             1.000000e+00  1.881630e+05  3.276710e+05
# assessmentyear                2.000000e+03  2.016000e+03  2.016000e+03
# landtaxvaluedollarcnt         1.000000e+00  7.966700e+04  1.838940e+05
# taxamount                     1.850000e+00  2.534918e+03  4.108900e+03
# taxdelinquencyyear            0.000000e+00  1.400000e+01  1.400000e+01
# censustractandblock          -1.000000e+00  6.037402e+13  6.037571e+13
# id                            0.000000e+00  1.954625e+04  3.892750e+04
# logerror                     -4.655420e+00 -2.463935e-02  7.009984e-03
#
#                                        75%           max
# parcelid                      1.405608e+07  1.696019e+08
# typeconstructiontypeid        6.000000e+00  1.300000e+01
# storytypeid                   7.000000e+00  7.000000e+00
# propertylandusetypeid         2.610000e+02  2.790000e+02
# heatingorsystemtypeid         7.000000e+00  2.400000e+01
# buildingclasstypeid           4.000000e+00  4.000000e+00
# architecturalstyletypeid      7.000000e+00  2.100000e+01
# airconditioningtypeid         1.000000e+00  1.300000e+01
# id                            2.235865e+06  2.982282e+06
# basementsqft                  8.895000e+02  8.516000e+03
# bathroomcnt                   3.000000e+00  3.200000e+01
# bedroomcnt                    4.000000e+00  2.500000e+01
# buildingqualitytypeid         8.000000e+00  1.200000e+01
# calculatedbathnbr             3.000000e+00  3.200000e+01
# decktypeid                    6.600000e+01  6.600000e+01
# finishedfloor1squarefeet      1.697000e+03  3.130300e+04
# calculatedfinishedsquarefeet  2.208000e+03  9.525760e+05
# finishedsquarefeet12          2.210000e+03  6.369200e+04
# finishedsquarefeet13          9.720000e+02  1.488000e+03
# finishedsquarefeet15          3.223000e+03  1.721400e+04
# finishedsquarefeet50          1.704000e+03  4.190600e+04
# finishedsquarefeet6           1.336000e+03  9.525760e+05
# fips                          6.059000e+03  6.111000e+03
# fireplacecnt                  1.000000e+00  9.000000e+00
# fullbathcnt                   3.000000e+00  3.200000e+01
# garagecarcnt                  2.000000e+00  2.500000e+01
# garagetotalsqft               5.370000e+02  7.749000e+03
# hashottuborspa                1.000000e+00  1.000000e+00
# latitude                      3.417047e+07  3.481965e+07
# longitude                    -1.179442e+08 -1.175543e+08
# lotsizesquarefeet             8.551000e+03  3.710005e+08
# poolcnt                       1.000000e+00  1.000000e+00
# poolsizesum                   5.950000e+02  1.741000e+04
# pooltypeid10                  1.000000e+00  1.000000e+00
# pooltypeid2                   1.000000e+00  1.000000e+00
# pooltypeid7                   1.000000e+00  1.000000e+00
# rawcensustractandblock        6.059042e+07  6.111009e+07
# regionidcity                  4.483300e+04  3.965560e+05
# regionidcounty                3.101000e+03  3.101000e+03
# regionidneighborhood          2.746950e+05  7.641670e+05
# regionidzip                   9.698700e+04  3.996750e+05
# roomcnt                       5.000000e+00  9.600000e+01
# threequarterbathnbr           1.000000e+00  7.000000e+00
# unitcnt                       1.000000e+00  1.020000e+02
# yardbuildingsqft17            4.050000e+02  7.983000e+03
# yardbuildingsqft26            3.150000e+02  4.144000e+03
# yearbuilt                     1.976000e+03  2.016000e+03
# numberofstories               2.000000e+00  4.100000e+01
# fireplaceflag                 1.000000e+00  1.000000e+00
# structuretaxvaluedollarcnt    2.038630e+05  6.640493e+07
# taxvaluedollarcnt             5.345210e+05  9.842891e+07
# assessmentyear                2.016000e+03  2.016000e+03
# landtaxvaluedollarcnt         3.452790e+05  8.892195e+07
# taxamount                     6.414300e+03  1.337756e+06
# taxdelinquencyyear            1.500000e+01  9.900000e+01
# censustractandblock           6.059042e+13  4.830301e+14
# id                            5.809350e+04  7.761300e+04
# logerror                      4.069098e-02  5.262999e+00

# %%
def nulls_by_rows(df):
    return pd.concat([
        df.isna().sum(axis=1).rename('n_missing'),
        df.isna().mean(axis=1).rename('percent_missing'),
    ], axis=1).value_counts().sort_index()

# %%
def nulls_by_columns(df):
    return pd.concat([
        df.isna().sum().rename('count'),
        df.isna().mean().rename('percent')
    ], axis=1)

# %%
listof = nulls_by_columns(df)
listof
# Out:
#                           count   percent
# parcelid                      0  0.000000
# typeconstructiontypeid  2150328  0.998765
# storytypeid             2151451  0.999287
# propertylandusetypeid         0  0.000000
# heatingorsystemtypeid    728047  0.338157
# ...                         ...       ...
# buildingclassdesc       2152985  1.000000
# heatingorsystemdesc      728047  0.338157
# propertylandusedesc           0  0.000000
# storydesc               2151451  0.999287
# typeconstructiondesc    2150328  0.998765
#
# [69 rows x 2 columns]

# %%
def handle_missing_values(df, prop_required_column, prop_required_row):
    n_required_column = round(df.shape[0] * prop_required_column)
    n_required_row = round(df.shape[1] * prop_required_row)
    df = df.dropna(axis=0, thresh=n_required_row)
    df = df.dropna(axis=1, thresh=n_required_column)
    return df

# %%
def overview(df):
    print('--- Shape: {}'.format(df.shape))
    print('--- Info')
    df.info()
    print('--- Column Descriptions')
    print(df.describe(include='all'))

# %%
overview = overview(df)
overview
# Out:
# --- Shape: (2152986, 69)
# --- Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2152986 entries, 0 to 2152985
# Data columns (total 69 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   parcelid                      int64
#  1   typeconstructiontypeid        float64
#  2   storytypeid                   float64
#  3   propertylandusetypeid         float64
#  4   heatingorsystemtypeid         float64
#  5   buildingclasstypeid           float64
#  6   architecturalstyletypeid      float64
#  7   airconditioningtypeid         float64
#  8   id                            int64
#  9   basementsqft                  float64
#  10  bathroomcnt                   float64
#  11  bedroomcnt                    float64
#  12  buildingqualitytypeid         float64
#  13  calculatedbathnbr             float64
#  14  decktypeid                    float64
#  15  finishedfloor1squarefeet      float64
#  16  calculatedfinishedsquarefeet  float64
#  17  finishedsquarefeet12          float64
#  18  finishedsquarefeet13          float64
#  19  finishedsquarefeet15          float64
#  20  finishedsquarefeet50          float64
#  21  finishedsquarefeet6           float64
#  22  fips                          float64
#  23  fireplacecnt                  float64
#  24  fullbathcnt                   float64
#  25  garagecarcnt                  float64
#  26  garagetotalsqft               float64
#  27  hashottuborspa                float64
#  28  latitude                      float64
#  29  longitude                     float64
#  30  lotsizesquarefeet             float64
#  31  poolcnt                       float64
#  32  poolsizesum                   float64
#  33  pooltypeid10                  float64
#  34  pooltypeid2                   float64
#  35  pooltypeid7                   float64
#  36  propertycountylandusecode     object
#  37  propertyzoningdesc            object
#  38  rawcensustractandblock        float64
#  39  regionidcity                  float64
#  40  regionidcounty                float64
#  41  regionidneighborhood          float64
#  42  regionidzip                   float64
#  43  roomcnt                       float64
#  44  threequarterbathnbr           float64
#  45  unitcnt                       float64
#  46  yardbuildingsqft17            float64
#  47  yardbuildingsqft26            float64
#  48  yearbuilt                     float64
#  49  numberofstories               float64
#  50  fireplaceflag                 float64
#  51  structuretaxvaluedollarcnt    float64
#  52  taxvaluedollarcnt             float64
#  53  assessmentyear                float64
#  54  landtaxvaluedollarcnt         float64
#  55  taxamount                     float64
#  56  taxdelinquencyflag            object
#  57  taxdelinquencyyear            float64
#  58  censustractandblock           float64
#  59  id                            float64
#  60  logerror                      float64
#  61  transactiondate               object
#  62  airconditioningdesc           object
#  63  architecturalstyledesc        object
#  64  buildingclassdesc             object
#  65  heatingorsystemdesc           object
#  66  propertylandusedesc           object
#  67  storydesc                     object
#  68  typeconstructiondesc          object
# dtypes: float64(56), int64(2), object(11)
# memory usage: 1.1+ GB
# --- Column Descriptions
#             parcelid  typeconstructiontypeid  storytypeid  \
# count   2.152986e+06             2658.000000       1535.0
# unique           NaN                     NaN          NaN
# top              NaN                     NaN          NaN
# freq             NaN                     NaN          NaN
# mean    1.309662e+07                5.981189          7.0
# std     5.172433e+06                0.348695          0.0
# min     1.071172e+07                4.000000          7.0
# 25%     1.165907e+07                6.000000          7.0
# 50%     1.259850e+07                6.000000          7.0
# 75%     1.405608e+07                6.000000          7.0
# max     1.696019e+08               13.000000          7.0
#
#         propertylandusetypeid  heatingorsystemtypeid  buildingclasstypeid  \
# count            2.152986e+06           1.424939e+06                  1.0
# unique                    NaN                    NaN                  NaN
# top                       NaN                    NaN                  NaN
# freq                      NaN                    NaN                  NaN
# mean             2.610000e+02           4.107412e+00                  4.0
# std              1.226738e-02           2.560808e+00                  NaN
# min              2.610000e+02           1.000000e+00                  4.0
# 25%              2.610000e+02           2.000000e+00                  4.0
# 50%              2.610000e+02           2.000000e+00                  4.0
# 75%              2.610000e+02           7.000000e+00                  4.0
# max              2.790000e+02           2.400000e+01                  4.0
#
#         architecturalstyletypeid  airconditioningtypeid            id  \
# count                2393.000000          513912.000000  2.152986e+06
# unique                       NaN                    NaN           NaN
# top                          NaN                    NaN           NaN
# freq                         NaN                    NaN           NaN
# mean                    7.187631               2.405684  1.490843e+06
# std                     2.739586               3.785911  8.608785e+05
# min                     2.000000               1.000000  1.000000e+00
# 25%                     7.000000               1.000000  7.451292e+05
# 50%                     7.000000               1.000000  1.490640e+06
# 75%                     7.000000               1.000000  2.235865e+06
# max                    21.000000              13.000000  2.982282e+06
#
#         basementsqft  ...            id      logerror  transactiondate  \
# count    1538.000000  ...  52442.000000  52442.000000            52442
# unique           NaN  ...           NaN           NaN              258
# top              NaN  ...           NaN           NaN       2017-06-30
# freq             NaN  ...           NaN           NaN              810
# mean      651.190507  ...  38860.631917      0.018294              NaN
# std       552.078809  ...  22348.437271      0.177502              NaN
# min        20.000000  ...      0.000000     -4.655420              NaN
# 25%       261.750000  ...  19546.250000     -0.024639              NaN
# 50%       519.500000  ...  38927.500000      0.007010              NaN
# 75%       889.500000  ...  58093.500000      0.040691              NaN
# max      8516.000000  ...  77613.000000      5.262999              NaN
#
#         airconditioningdesc  architecturalstyledesc  \
# count                513912                    2393
# unique                    7                       7
# top                 Central            Contemporary
# freq                 447959                    2124
# mean                    NaN                     NaN
# std                     NaN                     NaN
# min                     NaN                     NaN
# 25%                     NaN                     NaN
# 50%                     NaN                     NaN
# 75%                     NaN                     NaN
# max                     NaN                     NaN
#
#                                      buildingclassdesc  heatingorsystemdesc  \
# count                                                1              1424939
# unique                                               1                   11
# top     Buildings having wood or wood and steel frames              Central
# freq                                                 1               828497
# mean                                               NaN                  NaN
# std                                                NaN                  NaN
# min                                                NaN                  NaN
# 25%                                                NaN                  NaN
# 50%                                                NaN                  NaN
# 75%                                                NaN                  NaN
# max                                                NaN                  NaN
#
#               propertylandusedesc  storydesc  typeconstructiondesc
# count                     2152986       1535                  2658
# unique                          2          1                     4
# top     Single Family Residential   Basement                 Frame
# freq                      2152985       1535                  2616
# mean                          NaN        NaN                   NaN
# std                           NaN        NaN                   NaN
# min                           NaN        NaN                   NaN
# 25%                           NaN        NaN                   NaN
# 50%                           NaN        NaN                   NaN
# 75%                           NaN        NaN                   NaN
# max                           NaN        NaN                   NaN
#
# [11 rows x 69 columns]

# %% [markdown]
# ## Prepare

# %% [markdown]
# 1. Remove any properties that are likely to be something other than single unit properties. (e.g. no duplexes, no land/lot, ...). There are multiple ways to estimate that a property is a single unit, and there is not a single "right" answer.
#
# 2. Create a function that will drop rows or columns based on the percent of values that are missing: handle_missing_values(df, prop_required_column, prop_required_row).
# - The input:
#   -  A dataframe
#   -  A number between 0 and 1 that represents the proportion, for each column, of rows with non-missing values required to keep the column. i.e. if prop_required_column = .6, then you are requiring a column to have at least 60% of values not-NA (no more than 40% missing).
#   -  A number between 0 and 1 that represents the proportion, for each row, of columns/variables with non-missing values required to keep the row. For example, if prop_required_row = .75, then you are requiring a row to have at least 75% of variables with a non-missing value (no more that 25% missing).
# - The output:
#   -  The dataframe with the columns and rows dropped as indicated. Be sure to drop the columns prior to the rows in your function.
# - hint:
#   -  Look up the dropna documentation.
#   -  You will want to compute a threshold from your input values (prop_required) and total number of rows or columns.
#
# 3. Encapsulate your work inside of functions in a wrangle_zillow.py module.

# %%
def handle_missing_values(df, prop_required_column, prop_required_row):
    n_required_column = round(df.shape[0] * prop_required_column)
    n_required_row = round(df.shape[1] * prop_required_row)
    df = df.dropna(axis=0, thresh=n_required_row)
    df = df.dropna(axis=1, thresh=n_required_column)
    return df

# %%
missing_values = handle_missing_values(df)
missing_values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/cs/9mn89l_n6p3c9sq01q5f54kh0000gn/T/ipykernel_55749/3392101713.py in <module>
# ----> 1 missing_values = handle_missing_values(df)
#       2 missing_values
#
# TypeError: handle_missing_values() missing 2 required positional arguments: 'prop_required_column' and 'prop_required_row'
