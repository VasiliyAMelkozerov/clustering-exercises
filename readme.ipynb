# %% [markdown]
# # Zillow clustering project

# %% [markdown]
# Your readme includes a project plan which helps guide both the user and yourself through the different stages of the pipeline and steps you took to get to your conclusion

# %% [markdown]
# The project plan here is to zoom in on the probelm and see if I can find what is driving the issue of logerror

# %% [markdown]
# To do's:
# - set a floor and ceiling in my data
# - cluster the data into useful

# %% [markdown]
# ![data_dictionary.jpeg](attachment:data_dictionary.jpeg)

# %% [markdown]
# The goals of this project is to find the drivers of logerror. As well as build a model to help alleviate the logerror

# %% [markdown]
# Initial questions?:
#  - where are the logerrors occuring
#  - where if any are the patterns
#  - how can I use clusters to help find my results
