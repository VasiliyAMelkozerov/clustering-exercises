# %%
import pandas as pd
import seaborn as sns
import acquire

# %% [markdown]
# ## Acquire and Summarize

# %% [markdown]
# 1. Acquire data from the cloud database.
#
#     You will want to end with a single dataframe. Include the logerror field and all other fields related to the properties that are available. You will end up using all the tables in the database.
#
#     <b><i>Be sure to do the correct join (inner, outer, etc.). We do not want to eliminate properties purely because they may have a null value for airconditioningtypeid.</i></b> - Only include properties with a transaction in 2017, and include only the last transaction for each property (so no duplicate property ID's), along with zestimate error and date of transaction. (Hint: read the docs for the .duplicated method) - Only include properties that have a latitude and longitude value.
#
#
# 2. Summarize your data (summary stats, info, dtypes, shape, distributions, value_counts, etc.)
#
#
# 3. Write a function that takes in a dataframe of observations and attributes and returns a dataframe where each row is an atttribute name, the first column is the number of rows with missing values for that attribute, and the second column is percent of total rows that have missing values for that attribute. Run the function and document takeaways from this on how you want to handle missing values.

# %%
df = acquire.zillow_data()
df
# Out:
#        parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 0      14297519                     NaN          NaN                  261.0
# 1      17052889                     NaN          NaN                  261.0
# 2      14186244                     NaN          NaN                  261.0
# 3      12177905                     NaN          NaN                  261.0
# 4      12095076                     NaN          NaN                  261.0
# ...         ...                     ...          ...                    ...
# 52436  12412492                     NaN          NaN                  261.0
# 52437  11000655                     NaN          NaN                  261.0
# 52438  17239384                     NaN          NaN                  261.0
# 52439  12773139                     NaN          NaN                  261.0
# 52440  12826780                     NaN          NaN                  261.0
#
#        heatingorsystemtypeid buildingclasstypeid  architecturalstyletypeid  \
# 0                        NaN                None                       NaN
# 1                        NaN                None                       NaN
# 2                        NaN                None                       NaN
# 3                        2.0                None                       NaN
# 4                        2.0                None                       NaN
# ...                      ...                 ...                       ...
# 52436                    2.0                None                       NaN
# 52437                    2.0                None                       NaN
# 52438                    NaN                None                       NaN
# 52439                    2.0                None                       NaN
# 52440                    2.0                None                       NaN
#
#        airconditioningtypeid       id  basementsqft  ...     id  logerror  \
# 0                        NaN  1727539           NaN  ...      0  0.025595
# 1                        NaN  1387261           NaN  ...      1  0.055619
# 2                        NaN    11677           NaN  ...      2  0.005383
# 3                        NaN  2288172           NaN  ...      3 -0.103410
# 4                        1.0   781532           NaN  ...      6 -0.001011
# ...                      ...      ...           ...  ...    ...       ...
# 52436                    NaN  2274245           NaN  ...  77607  0.001082
# 52437                    NaN   673515           NaN  ...  77609  0.020615
# 52438                    NaN  2968375           NaN  ...  77610  0.013209
# 52439                    1.0  1843709           NaN  ...  77611  0.037129
# 52440                    NaN  1187175           NaN  ...  77612  0.007204
#
#        transactiondate  airconditioningdesc  architecturalstyledesc  \
# 0           2017-01-01                 None                    None
# 1           2017-01-01                 None                    None
# 2           2017-01-01                 None                    None
# 3           2017-01-01                 None                    None
# 4           2017-01-01              Central                    None
# ...                ...                  ...                     ...
# 52436       2017-09-19                 None                    None
# 52437       2017-09-20                 None                    None
# 52438       2017-09-21                 None                    None
# 52439       2017-09-21              Central                    None
# 52440       2017-09-25                 None                    None
#
#        buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
# 0                   None                 None  Single Family Residential
# 1                   None                 None  Single Family Residential
# 2                   None                 None  Single Family Residential
# 3                   None              Central  Single Family Residential
# 4                   None              Central  Single Family Residential
# ...                  ...                  ...                        ...
# 52436               None              Central  Single Family Residential
# 52437               None              Central  Single Family Residential
# 52438               None                 None  Single Family Residential
# 52439               None              Central  Single Family Residential
# 52440               None              Central  Single Family Residential
#
#       storydesc typeconstructiondesc
# 0          None                 None
# 1          None                 None
# 2          None                 None
# 3          None                 None
# 4          None                 None
# ...         ...                  ...
# 52436      None                 None
# 52437      None                 None
# 52438      None                 None
# 52439      None                 None
# 52440      None                 None
#
# [52441 rows x 69 columns]

# %%
df.shape
# Out:
# (52441, 69)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52441 entries, 0 to 52440
# Data columns (total 69 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      52441 non-null  int64
#  1   typeconstructiontypeid        76 non-null     float64
#  2   storytypeid                   47 non-null     float64
#  3   propertylandusetypeid         52441 non-null  float64
#  4   heatingorsystemtypeid         33935 non-null  float64
#  5   buildingclasstypeid           0 non-null      object
#  6   architecturalstyletypeid      70 non-null     float64
#  7   airconditioningtypeid         13638 non-null  float64
#  8   id                            52441 non-null  int64
#  9   basementsqft                  47 non-null     float64
#  10  bathroomcnt                   52441 non-null  float64
#  11  bedroomcnt                    52441 non-null  float64
#  12  buildingqualitytypeid         33740 non-null  float64
#  13  calculatedbathnbr             52304 non-null  float64
#  14  decktypeid                    389 non-null    float64
#  15  finishedfloor1squarefeet      4381 non-null   float64
#  16  calculatedfinishedsquarefeet  52359 non-null  float64
#  17  finishedsquarefeet12          52194 non-null  float64
#  18  finishedsquarefeet13          0 non-null      object
#  19  finishedsquarefeet15          0 non-null      object
#  20  finishedsquarefeet50          4381 non-null   float64
#  21  finishedsquarefeet6           165 non-null    float64
#  22  fips                          52441 non-null  float64
#  23  fireplacecnt                  7243 non-null   float64
#  24  fullbathcnt                   52304 non-null  float64
#  25  garagecarcnt                  18015 non-null  float64
#  26  garagetotalsqft               18015 non-null  float64
#  27  hashottuborspa                1515 non-null   float64
#  28  latitude                      52441 non-null  float64
#  29  longitude                     52441 non-null  float64
#  30  lotsizesquarefeet             52072 non-null  float64
#  31  poolcnt                       11096 non-null  float64
#  32  poolsizesum                   867 non-null    float64
#  33  pooltypeid10                  444 non-null    float64
#  34  pooltypeid2                   1071 non-null   float64
#  35  pooltypeid7                   10009 non-null  float64
#  36  propertycountylandusecode     52441 non-null  object
#  37  propertyzoningdesc            33848 non-null  object
#  38  rawcensustractandblock        52441 non-null  float64
#  39  regionidcity                  51404 non-null  float64
#  40  regionidcounty                52441 non-null  float64
#  41  regionidneighborhood          19033 non-null  float64
#  42  regionidzip                   52415 non-null  float64
#  43  roomcnt                       52441 non-null  float64
#  44  threequarterbathnbr           6724 non-null   float64
#  45  unitcnt                       33847 non-null  float64
#  46  yardbuildingsqft17            1937 non-null   float64
#  47  yardbuildingsqft26            63 non-null     float64
#  48  yearbuilt                     52325 non-null  float64
#  49  numberofstories               14561 non-null  float64
#  50  fireplaceflag                 81 non-null     float64
#  51  structuretaxvaluedollarcnt    52357 non-null  float64
#  52  taxvaluedollarcnt             52440 non-null  float64
#  53  assessmentyear                52441 non-null  float64
#  54  landtaxvaluedollarcnt         52440 non-null  float64
#  55  taxamount                     52437 non-null  float64
#  56  taxdelinquencyflag            2079 non-null   object
#  57  taxdelinquencyyear            2079 non-null   float64
#  58  censustractandblock           52318 non-null  float64
#  59  id                            52441 non-null  int64
#  60  logerror                      52441 non-null  float64
#  61  transactiondate               52441 non-null  object
nt                       1.000000e+00  1.000000e+00  1.000000e+00
# yardbuildingsqft17            1.100000e+01  2.000000e+02  2.800000e+02
# yardbuildingsqft26            1.200000e+01  7.150000e+01  1.800000e+02
# yearbuilt                     1.878000e+03  1.950000e+03  1.961000e+03
# numberofstories               1.000000e+00  1.000000e+00  1.000000e+00
# fireplaceflag                 1.000000e+00  1.000000e+00  1.000000e+00
# structuretaxvaluedollarcnt    1.290000e+02  7.707100e+04  1.318110e+05
# taxvaluedollarcnt             1.000000e+03  1.937475e+05  3.736120e+05
# assessmentyear                2.016000e+03  2.016000e+03  2.016000e+03
# landtaxvaluedollarcnt         1.610000e+02  7.602075e+04  2.180320e+05
# taxamount                     4.918000e+01  2.656220e+03  4.647740e+03
# taxdelinquencyyear            4.000000e+00  1.400000e+01  1.500000e+01
# censustractandblock           6.037101e+13  6.037401e+13  6.037620e+13
# id                            0.000000e+00  1.954600e+04  3.892700e+04
# logerror                     -4.655420e+00 -2.463880e-02  7.010779e-03
#
#                                        75%           max
# parcelid                      1.412953e+07  1.676878e+08
# typeconstructiontypeid        6.000000e+00  6.000000e+00
# storytypeid                   7.000000e+00  7.000000e+00
# propertylandusetypeid         2.610000e+02  2.610000e+02
# heatingorsystemtypeid         7.000000e+00  2.400000e+01
# architecturalstyletypeid      7.000000e+00  2.100000e+01
# airconditioningtypeid         1.000000e+00  1.300000e+01
# id                            2.241534e+06  2.982270e+06
# basementsqft                  8.095000e+02  3.560000e+03
# bathroomcnt                   3.000000e+00  1.800000e+01
# bedroomcnt                    4.000000e+00  1.400000e+01
# buildingqualitytypeid         8.000000e+00  1.200000e+01
# calculatedbathnbr             3.000000e+00  1.800000e+01
# decktypeid                    6.600000e+01  6.600000e+01
# finishedfloor1squarefeet      1.759000e+03  6.912000e+03
# calculatedfinishedsquarefeet  2.306000e+03  2.192900e+04
# finishedsquarefeet12          2.308000e+03  2.192900e+04
# finishedsquarefeet50          1.770000e+03  1.246700e+04
# finishedsquarefeet6           1.320000e+03  5.598000e+03
# fips                          6.059000e+03  6.111000e+03
# fireplacecnt                  1.000000e+00  5.000000e+00
# fullbathcnt                   3.000000e+00  1.800000e+01
# garagecarcnt                  2.000000e+00  1.400000e+01
# garagetotalsqft               5.670000e+02  4.251000e+03
# hashottuborspa                1.000000e+00  1.000000e+00
# latitude                      3.418715e+07  3.481877e+07
# longitude                    -1.179292e+08 -1.175546e+08
# lotsizesquarefeet             8.798250e+03  6.971010e+06
# poolcnt                       1.000000e+00  1.000000e+00
# poolsizesum                   6.000000e+02  1.500000e+03
# pooltypeid10                  1.000000e+00  1.000000e+00
# pooltypeid2                   1.000000e+00  1.000000e+00
# pooltypeid7                   1.000000e+00  1.000000e+00
# rawcensustractandblock        6.059042e+07  6.111009e+07
# regionidcity                  4.022700e+04  3.965560e+05
# regionidcounty                3.101000e+03  3.101000e+03
# regionidneighborhood          2.745140e+05  7.641670e+05
# regionidzip                   9.699500e+04  3.996750e+05
# roomcnt                       5.000000e+00  1.500000e+01
# threequarterbathnbr           1.000000e+00  7.000000e+00
# unitcnt                       1.000000e+00  3.000000e+00
# yardbuildingsqft17            4.000000e+02  3.191000e+03
# yardbuildingsqft26            3.170000e+02  8.680000e+02
# yearbuilt                     1.979000e+03  2.016000e+03
# numberofstories               2.000000e+00  6.000000e+00
# fireplaceflag                 1.000000e+00  1.000000e+00
# structuretaxvaluedollarcnt    2.263340e+05  9.164901e+06
# taxvaluedollarcnt             6.193012e+05  4.906124e+07
# assessmentyear                2.016000e+03  2.016000e+03
# landtaxvaluedollarcnt         4.086068e+05  4.895220e+07
# taxamount                     7.377500e+03  5.866393e+05
# taxdelinquencyyear            1.500000e+01  9.900000e+01
# censustractandblock           6.059042e+13  4.830301e+14
# id                            5.809200e+04  7.761200e+04
# logerror                      4.069204e-02  5.262999e+00

# %%
def nulls_by_rows(df):
    return pd.concat([
        df.isna().sum(axis=1).rename('n_missing'),
        df.isna().mean(axis=1).rename('percent_missing'),
    ], axis=1).value_counts().sort_index()

# %%
def nulls_by_columns(df):
    return pd.concat([
        df.isna().sum().rename('count'),
        df.isna().mean().rename('percent')
    ], axis=1)

# %%
listof = nulls_by_columns(df)
listof
# Out:
#                         count   percent
# parcelid                    0  0.000000
# typeconstructiontypeid  52365  0.998551
# storytypeid             52394  0.999104
# propertylandusetypeid       0  0.000000
# heatingorsystemtypeid   18506  0.352892
# ...                       ...       ...
# buildingclassdesc       52441  1.000000
# heatingorsystemdesc     18506  0.352892
# propertylandusedesc         0  0.000000
# storydesc               52394  0.999104
# typeconstructiondesc    52365  0.998551
#
# [69 rows x 2 columns]

# %%
def handle_missing_values(df, prop_required_column, prop_required_row):
    n_required_column = round(df.shape[0] * prop_required_column)
    n_required_row = round(df.shape[1] * prop_required_row)
    df = df.dropna(axis=0, thresh=n_required_row)
    df = df.dropna(axis=1, thresh=n_required_column)
    return df

# %%
def overview(df):
    print('--- Shape: {}'.format(df.shape))
    print('--- Info')
    df.info()
    print('--- Column Descriptions')
    print(df.describe(include='all'))

# %%
overview = overview(df)
overview
# Out:
# --- Shape: (52441, 69)
# --- Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52441 entries, 0 to 52440
# Data columns (total 69 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      52441 non-null  int64
#  1   typeconstructiontypeid        76 non-null     float64
#  2   storytypeid                   47 non-null     float64
#  3   propertylandusetypeid         52441 non-null  float64
#  4   heatingorsystemtypeid         33935 non-null  float64
#  5   buildingclasstypeid           0 non-null      object
#  6   architecturalstyletypeid      70 non-null     float64
#  7   airconditioningtypeid         13638 non-null  float64
#  8   id                            52441 non-null  int64
#  9   basementsqft                  47 non-null     float64
#  10  bathroomcnt                   52441 non-null  float64
#  11  bedroomcnt                    52441 non-null  float64
#  12  buildingqualitytypeid         33740 non-null  float64
#  13  calculatedbathnbr             52304 non-null  float64
#  14  decktypeid                    389 non-null    float64
#  15  finishedfloor1squarefeet      4381 non-null   float64
#  16  calculatedfinishedsquarefeet  52359 non-null  float64
#  17  finishedsquarefeet12          52194 non-null  float64
#  18  finishedsquarefeet13          0 non-null      object
#  19  finishedsquarefeet15          0 non-null      object
#  20  finishedsquarefeet50          4381 non-null   float64
#  21  finishedsquarefeet6           165 non-null    float64
#  22  fips                          52441 non-null  float64
#  23  fireplacecnt                  7243 non-null   float64
#  24  fullbathcnt                   52304 non-null  float64
#  25  garagecarcnt                  18015 non-null  float64
#  26  garagetotalsqft               18015 non-null  float64
#  27  hashottuborspa                1515 non-null   float64
#  28  latitude                      52441 non-null  float64
#  29  longitude                     52441 non-null  float64
#  30  lotsizesquarefeet             52072 non-null  float64
#  31  poolcnt                       11096 non-null  float64
#  32  poolsizesum                   867 non-null    float64
#  33  pooltypeid10                  444 non-null    float64
#  34  pooltypeid2                   1071 non-null   float64
#  35  pooltypeid7                   10009 non-null  float64
#  36  propertycountylandusecode     52441 non-null  object
#  37  propertyzoningdesc            33848 non-null  object
#  38  rawcensustractandblock        52441 non-null  float64
#  39  regionidcity                  51404 non-null  float64
#  40  regionidcounty                52441 non-null  float64
#  41  regionidneighborhood          19033 non-null  float64
#  42  regionidzip                   52415 non-null  float64
#  43  roomcnt                       52441 non-null  float64
#  44  threequarterbathnbr           6724 non-null   float64
#  45  unitcnt                       33847 non-null  float64
#  46  yardbuildingsqft17            1937 non-null   float64
#  47  yardbuildingsqft26            63 non-null     float64
#  48  yearbuilt                     52325 non-null  float64
#  49  numberofstories               14561 non-null  float64
#  50  fireplaceflag                 81 non-null     float64
#  51  structuretaxvaluedollarcnt    52357 non-null  float64
#  52  taxvaluedollarcnt             52440 non-null  float64
#  53  assessmentyear                52441 non-null  float64
#  54  landtaxvaluedollarcnt         52440 non-null  float64
#  55  taxamount                     52437 non-null  float64
#  56  taxdelinquencyflag            2079 non-null   object
#  57  taxdelinquencyyear            2079 non-null   float64
#  58  censustractandblock           52318 non-null  float64
#  59  id                            52441 non-null  int64
#  60  logerror                      52441 non-null  float64
#  61  transactiondate               52441 non-null  object
#  62  airconditioningdesc           13638 non-null  object
#  63  architecturalstyledesc        70 non-null     object
#  64  buildingclassdesc             0 non-null      object
#  65  heatingorsystemdesc           33935 non-null  object
#  66  propertylandusedesc           52441 non-null  object
#  67  storydesc                     47 non-null     object
#  68  typeconstructiondesc          76 non-null     object
# dtypes: float64(52), int64(3), object(14)
# memory usage: 27.6+ MB
# --- Column Descriptions
#             parcelid  typeconstructiontypeid  storytypeid  \
# count   5.244100e+04               76.000000         47.0
# unique           NaN                     NaN          NaN
# top              NaN                     NaN          NaN
# freq             NaN                     NaN          NaN
# mean    1.299912e+07                5.973684          7.0
# std     3.411444e+06                0.229416          0.0
# min     1.071186e+07                4.000000          7.0
# 25%     1.151022e+07                6.000000          7.0
# 50%     1.257764e+07                6.000000          7.0
# 75%     1.412953e+07                6.000000          7.0
# max     1.676878e+08                6.000000          7.0
#
#         propertylandusetypeid  heatingorsystemtypeid buildingclasstypeid  \
# count                 52441.0           33935.000000                   0
# unique                    NaN                    NaN                   0
# top                       NaN                    NaN                 NaN
# freq                      NaN                    NaN                 NaN
# mean                    261.0               3.966288                 NaN
# std                       0.0               2.562506                 NaN
# min                     261.0               1.000000                 NaN
# 25%                     261.0               2.000000                 NaN
# 50%                     261.0               2.000000                 NaN
# 75%                     261.0               7.000000                 NaN
# max                     261.0              24.000000                 NaN
#
#         architecturalstyletypeid  airconditioningtypeid            id  \
# count                   70.00000           13638.000000  5.244100e+04
# unique                       NaN                    NaN           NaN
# top                          NaN                    NaN           NaN
# freq                         NaN                    NaN           NaN
# mean                     7.10000               2.438041  1.497270e+06
# std                      2.66567               3.846176  8.594393e+05
# min                      2.00000               1.000000  3.490000e+02
# 25%                      7.00000               1.000000  7.579550e+05
# 50%                      7.00000               1.000000  1.500810e+06
# 75%                      7.00000               1.000000  2.241534e+06
# max                     21.00000              13.000000  2.982270e+06
#
#         basementsqft  ...            id      logerror  transactiondate  \
# count      47.000000  ...  52441.000000  52441.000000            52441
# unique           NaN  ...           NaN           NaN              257
# top              NaN  ...           NaN           NaN       2017-06-30
# freq             NaN  ...           NaN           NaN              810
# mean      678.978723  ...  38859.892946      0.018298              NaN
# std       711.825226  ...  22348.009638      0.177501              NaN
# min        38.000000  ...      0.000000     -4.655420              NaN
# 25%       263.500000  ...  19546.000000     -0.024639              NaN
# 50%       512.000000  ...  38927.000000      0.007011              NaN
# 75%       809.500000  ...  58092.000000      0.040692              NaN
# max      3560.000000  ...  77612.000000      5.262999              NaN
#
#         airconditioningdesc  architecturalstyledesc  buildingclassdesc  \
# count                 13638                      70                  0
# unique                    4                       5                  0
# top                 Central            Contemporary                NaN
# freq                  11895                      62                NaN
# mean                    NaN                     NaN                NaN
# std                     NaN                     NaN                NaN
# min                     NaN                     NaN                NaN
# 25%                     NaN                     NaN                NaN
# 50%                     NaN                     NaN                NaN
# 75%                     NaN                     NaN                NaN
# max                     NaN                     NaN                NaN
#
#         heatingorsystemdesc        propertylandusedesc storydesc  \
# count                 33935                      52441        47
# unique                    9                          1         1
# top                 Central  Single Family Residential  Basement
# freq                  20736                      52441        47
# mean                    NaN                        NaN       NaN
# std                     NaN                        NaN       NaN
# min                     NaN                        NaN       NaN
# 25%                     NaN                        NaN       NaN
# 50%                     NaN                        NaN       NaN
# 75%                     NaN                        NaN       NaN
# max                     NaN                        NaN       NaN
#
#        typeconstructiondesc
# count                    76
# unique                    2
# top                   Frame
# freq                     75
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN
#
# [11 rows x 69 columns]

# %% [markdown]
# ## Prepare

# %% [markdown]
# 1. Remove any properties that are likely to be something other than single unit properties. (e.g. no duplexes, no land/lot, ...). There are multiple ways to estimate that a property is a single unit, and there is not a single "right" answer.
#
# 2. Create a function that will drop rows or columns based on the percent of values that are missing: handle_missing_values(df, prop_required_column, prop_required_row).
# - The input:
#   -  A dataframe
#   -  A number between 0 and 1 that represents the proportion, for each column, of rows with non-missing values required to keep the column. i.e. if prop_required_column = .6, then you are requiring a column to have at least 60% of values not-NA (no more than 40% missing).
#   -  A number between 0 and 1 that represents the proportion, for each row, of columns/variables with non-missing values required to keep the row. For example, if prop_required_row = .75, then you are requiring a row to have at least 75% of variables with a non-missing value (no more that 25% missing).
# - The output:
#   -  The dataframe with the columns and rows dropped as indicated. Be sure to drop the columns prior to the rows in your function.
# - hint:
#   -  Look up the dropna documentation.
#   -  You will want to compute a threshold from your input values (prop_required) and total number of rows or columns.
#
# 3. Encapsulate your work inside of functions in a wrangle_zillow.py module.

# %%
def handle_missing_values(df, prop_required_column, prop_required_row):
    n_required_column = round(df.shape[0] * prop_required_column)
    n_required_row = round(df.shape[1] * prop_required_row)
    df = df.dropna(axis=0, thresh=n_required_row)
    df = df.dropna(axis=1, thresh=n_required_column)
    return df

# %%
missing_values = handle_missing_values(df,.5,.25)
missing_values
# Out:
#        parcelid  propertylandusetypeid  heatingorsystemtypeid       id  \
# 0      14297519                  261.0                    NaN  1727539
# 1      17052889                  261.0                    NaN  1387261
# 2      14186244                  261.0                    NaN    11677
# 3      12177905                  261.0                    2.0  2288172
# 4      12095076                  261.0                    2.0   781532
# ...         ...                    ...                    ...      ...
# 52436  12412492                  261.0                    2.0  2274245
# 52437  11000655                  261.0                    2.0   673515
# 52438  17239384                  261.0                    NaN  2968375
# 52439  12773139                  261.0                    2.0  1843709
# 52440  12826780                  261.0                    2.0  1187175
#
#        bathroomcnt  bedroomcnt  buildingqualitytypeid  calculatedbathnbr  \
# 0              3.5         4.0                    NaN                3.5
# 1              1.0         2.0                    NaN                1.0
# 2              2.0         3.0                    NaN                2.0
# 3              3.0         4.0                    8.0                3.0
# 4              3.0         4.0                    9.0                3.0
# ...            ...         ...                    ...                ...
# 52436          2.0         4.0                    6.0                2.0
# 52437          2.0         2.0                    6.0                2.0
# 52438          2.0         4.0                    NaN                2.0
# 52439          1.0         3.0                    4.0                1.0
# 52440          2.0         3.0                    6.0                2.0
#
#        calculatedfinishedsquarefeet  finishedsquarefeet12  ...  \
# 0                            3100.0                3100.0  ...
# 1                            1465.0                1465.0  ...
# 2                            1243.0                1243.0  ...
# 3                            2376.0                2376.0  ...
# 4                            2962.0                2962.0  ...
# ...                             ...                   ...  ...
# 52436                        1633.0                1633.0  ...
# 52437                        1286.0                1286.0  ...
# 52438                        1612.0                1612.0  ...
# 52439                        1032.0                1032.0  ...
# 52440                        1762.0                1762.0  ...
#
#        taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0              1023282.0          2016.0               537569.0   11013.72
# 1               464000.0          2016.0               376000.0    5672.48
# 2               564778.0          2016.0               479489.0    6488.30
# 3               145143.0          2016.0                36225.0    1777.51
# 4               773303.0          2016.0               496619.0    9516.26
# ...                  ...             ...                    ...        ...
# 52436           346534.0          2016.0               221068.0    4175.08
# 52437           354621.0          2016.0               283704.0    4478.43
# 52438            67205.0          2016.0                16522.0    1107.48
# 52439            49546.0          2016.0                16749.0     876.43
# 52440           522000.0          2016.0               382000.0    6317.15
#
#        censustractandblock     id  logerror  transactiondate  \
# 0             6.059063e+13      0  0.025595       2017-01-01
# 1             6.111001e+13      1  0.055619       2017-01-01
# 2             6.059022e+13      2  0.005383       2017-01-01
# 3             6.037300e+13      3 -0.103410       2017-01-01
# 4             6.037461e+13      6 -0.001011       2017-01-01
# ...                    ...    ...       ...              ...
# 52436         6.037555e+13  77607  0.001082       2017-09-19
# 52437         6.037101e+13  77609  0.020615       2017-09-20
# 52438         6.111008e+13  77610  0.013209       2017-09-21
# 52439         6.037434e+13  77611  0.037129       2017-09-21
# 52440         6.037503e+13  77612  0.007204       2017-09-25
#
#        heatingorsystemdesc        propertylandusedesc
# 0                     None  Single Family Residential
# 1                     None  Single Family Residential
# 2                     None  Single Family Residential
# 3                  Central  Single Family Residential
# 4                  Central  Single Family Residential
# ...                    ...                        ...
# 52436              Central  Single Family Residential
# 52437              Central  Single Family Residential
# 52438                 None  Single Family Residential
# 52439              Central  Single Family Residential
# 52440              Central  Single Family Residential
#
# [52441 rows x 35 columns]
